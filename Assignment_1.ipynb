# %% [markdown]
# # Assignment 1
#
# #### Due Date: 24th Jan'18
#
# In this assignment we will cover the basics of Machine Learning. We will cover the following topics:
#
# 1) Linear Regression
#
# 2) Logistic Regression
#
# 3) EM Algorithm
#
# 4) K-means/Hirarchical Clustering.
#
# It is crucial to get down to the nitty gritty of the code to implement all of these. No external packages (like scipy), which directly give functions for these algorithms, are to be used.

# %% [markdown]
# ## Linear Regression
#
# Defination: Given a data set ${\displaystyle \{y_{i},\,x_{i1},\ldots ,x_{ip}\}_{i=1}^{n}} $ of $n$ statistical units, a linear regression model assumes that the relationship between the dependent variable $y_i$ and the $p$-vector of regressors $x_i$ is linear. This relationship is modeled through a disturbance term or error variable $ε_i$ - an unobserved random variable that adds noise to the linear relationship between the dependent variable and regressors. Thus the model takes the form:
#
# $$ {\displaystyle \mathbf {y} =X{\boldsymbol {\beta }}+{\boldsymbol {\varepsilon }},\,} $$
#
# where,
#
# $$ \mathbf {y} ={\begin{pmatrix}y_{1}\\y_{2}\\\vdots \\y_{n}\end{pmatrix}},\quad $$
#
# $$ {\displaystyle X={\begin{pmatrix}\mathbf {x} _{1}^{\top }\\\mathbf {x} _{2}^{\top }\\\vdots \\\mathbf {x} _{n}^{\top }\end{pmatrix}}={\begin{pmatrix}1&x_{11}&\cdots &x_{1p}\\1&x_{21}&\cdots &x_{2p}\\\vdots &\vdots &\ddots &\vdots \\1&x_{n1}&\cdots &x_{np}\end{pmatrix}},}
# $$
#
# $$ {\displaystyle {\boldsymbol {\beta }}={\begin{pmatrix}\beta _{0}\\\beta _{1}\\\beta _{2}\\\vdots \\\beta _{p}\end{pmatrix}},\quad {\boldsymbol {\varepsilon }}={\begin{pmatrix}\varepsilon _{1}\\\varepsilon _{2}\\\vdots \\\varepsilon _{n}\end{pmatrix}}.}
# $$

# %% [markdown]
# For this problem, in the class lecture we covered the Least Square Solution, which can be formulated as:
#
# $${\displaystyle {\hat {\boldsymbol {\beta }}}=(\mathbf {X} ^{\top }\mathbf {X} )^{-1}\mathbf {X} ^{\top }\mathbf {y} =\left(\sum \mathbf {x} _{i}\mathbf {x} _{i}^{\top }\right)^{-1}\left(\sum \mathbf {x} _{i}y_{i}\right).} $$

# %% [markdown]
# ## Question 1
#
# a) You will write the code to find the LSS for the given data. The data contains 3 columns, each for $y, X_{1}$, and $X_{2}$ respectively. Few of the possible models are:
#
# $$ {\displaystyle \mathbf {y} ={\boldsymbol {\beta_{1} }}X_1+{\boldsymbol {\beta_{0} }}+{\boldsymbol {\varepsilon }},\,} $$
#
#
# $$ {\displaystyle \mathbf {y} ={\boldsymbol {\beta_{2} }}X_2+{\boldsymbol {\beta_{0} }}+{\boldsymbol {\varepsilon }},\,} $$
#
#
# $$ {\displaystyle \mathbf {y} ={\boldsymbol {\beta_{1} }}X_1+ {\boldsymbol {\beta_{2} }}X_2+{\boldsymbol {\beta_{0} }}+{\boldsymbol {\varepsilon }},\,} $$
#
# Given this data, find the coefficients for each of these models.
#
# b) Now that you have three models, you must select the best one. Use Cross-validation with 5 folds on the dataset to find the optimal model (On the basis of RMSE on the test partition).

# %%
import numpy
from math import sqrt
# Load the dataset 
train_data = np.load('utils/assign_1_data_1_train.npy')
# now write the code for finding the solution for each of the three models.

#Note the data format is assumed to be X1,X2,y

#Scoring functions
def RMSE(Y, Y_hat,n):
	return sqrt(np.sum(np.square(Y-Y_hat), axis=0)/n)


def SSE(Y, Y_hat,n):
	return RMSE(Y,Y_hat,n) * n

def TSS(Y, Y_hat,n):
	y_bar = np.sum(Y, axis=0)/n
	return np.sum(np.square(Y-y_bar),axis=0)

def R_square(Y, Y_hat,n):
	 return 1-(SSE(Y, Y_hat,n)/TSS(Y, Y_hat,n))

# %%
# Finally, Write The estimates of the betas here:

# Model 1
def model1Train(data):
	X = np.reshape(data[:,0],(240,1))
	X = np.insert(X,0,np.ones(240),axis=1)
	Y = np.reshape(data[:,2], (240,1))
	B = np.linalg.solve(np.matmul(np.transpose(X),X), np.matmul(np.transpose(X),Y))
	return B

def model1Test(data, B):
	X = np.reshape(data[:,0],(60,1))
	X = np.insert(X,0,np.ones(60),axis=1)
	Y = data[:,2]
	#print Y_hat
	Y = np.reshape(Y,(60,1))
	Y_hat = np.matmul(X,np.reshape(B,(2,1)))
	#print Y_hat
	return RMSE(Y, Y_hat,60)

# Model 2
def model2Train(data):
	X = np.reshape(data[:,1],(240,1))
	X = np.insert(X,0,np.ones(240),axis=1)
	Y = data[:,2]
	B = np.linalg.solve(np.matmul(np.transpose(X),X), np.matmul(np.transpose(X),Y))
	return B

def model2Test(data, B):
	X = np.reshape(data[:,1],(60,1))
	X = np.insert(X,0,np.ones(60),axis=1)
	Y = data[:,2]
	#print Y_hat
	Y = np.reshape(Y,(60,1))
	Y_hat = np.matmul(X,np.reshape(B,(2,1)))
	#print Y
	return RMSE(Y, Y_hat, 60)
# Model 3
def model3Train(data):
	X = data[:,0:2]
	X = np.insert(X,0,np.ones(240),axis=1)
	Y = data[:,2]
	B = np.linalg.solve(np.matmul(np.transpose(X),X), np.matmul(np.transpose(X),Y))
	return B

def model3Test(data, B):
	X = data[:,0:2]
	X = np.insert(X,0,np.ones(60),axis=1)
	Y = data[:,2]
	Y = np.reshape(Y,(60,1))
	#print Y_hat.shape
	Y_hat = np.matmul(X,np.reshape(B,(3,1)))
	#print Y.shape
	return RMSE(Y, Y_hat, 60)

def model3TestR2(data, B):
	X = data[:,0:2]
	X = np.insert(X,0,np.ones(150),axis=1)
	Y = data[:,2]
	Y = np.reshape(Y,(150,1))
	#print Y_hat.shape
	Y_hat = np.matmul(X,np.reshape(B,(3,1)))
	#print Y.shape
	return R_square(Y, Y_hat, 150)

# %%
# partition the dataset into 5 random folds.

# for each fold, approx. model from the remaining folds, and calculate RMSE on the test fold.

# find avg RMSE for each model. 

# Which is the best model?
RMSE_A = 0
RMSE_B = 0
RMSE_C = 0
for i in range(5):
	train_data = np.roll(train_data, 60, axis=0)

	B1 = model1Train(train_data[0:240,:])
	RMSE_A += model1Test(train_data[240:300,:], B1)

	B2 = model2Train(train_data[0:240,:])
	RMSE_B += model2Test(train_data[240:300,:], B2)

	B3 = model3Train(train_data[0:240,:])
	RMSE_C += model3Test(train_data[240:300,:], B3)

print 'Average RMSEs'
print 'A ', RMSE_A/5, 'B: ', RMSE_B/5, 'C: ', RMSE_C/5
# Out:
# Average RMSEs
# A  71.2882051869 B:  71.9204010094 C:  71.223145557

# %%
# Finally, Give the R^2 score of the best model in the test set:
#Since C is the best Model
test_data = np.load('utils/assign_1_data_1_test.npy')
print model3TestR2(test_data, B3)
# Out:
# [ 0.9861672]

# %%
# Bonus

# Show a graph between the predicted Y^ and the Ground truth Y

# Try to plot Y vs X_1 in train set.

# can it help you improve your model?
# construct the better model.

# %% [markdown]
# # Logistic Regression
#
# Generaly, Logistic Regression is used to predict categorial variables. For the simple problem of 2-way classification, the output $\hat{y_i}$ is modeled as the probability that $\{X_i\}$ belongs to class $1$ (given two classes $0$, and $1$).
#
# $$ P( \{X_i\} \in Set_1 ) = \hat{y_i}, $$ ( $y_i$ is the actual label; $y_i \in \{ 0,1 \}$ )
#
#
# $\hat{y_i}$ is typically modeled as the output of a sigmoid on a linear combination of the input feature $\{X_i\}$:
#
# $$ \mathbf {\hat{y}} = \sigma(X{\boldsymbol {\beta }}+{\boldsymbol {\varepsilon }}) = \sigma_\beta(X)$$

# %% [markdown]
# Now, The likelihood of some given data for this model can be written as:
#
# $${\displaystyle {\begin{aligned}L(\beta |x)&=Pr(Y|X;\beta )\\&=\prod _{i}Pr(y_{i}|x_{i};\beta )\\&=\prod _{i}\sigma_{\beta }(x_{i})^{y_{i}}(1-\sigma_{\beta }(x_{i}))^{(1-y_{i})}\end{aligned}}}$$

# %% [markdown]
# Unlike in the case of Linear regression, this equation has no closed form solution. Hence we will use gradient descent on the negative log-likelihood $J(\beta)$ to find the optimal $\beta$
#
# $$
# J(\beta) = \sum_i{\big( y_ilog(\hat{y_i})+ (1-y_i)log(1-\hat{y_i}) \big) }
# $$
#
# with the update equation:
#
# $$
# \beta_j = \beta_j + \alpha \times \frac{ \partial J(\beta)}{\partial \beta}
# $$

# %% [markdown]
# ## Question 2
#
# a) You will write the code to find the optimal logistic regression model for the given data. The data contains 3 columns, each for $y, X_{1}$, and $X_{2}$ respectively. For the rate of learning $\alpha$ use a linearly decaying policy, or step-wise reduction policy.
#
# $$ {\displaystyle \mathbf {y} =\sigma \big( {\boldsymbol {\beta_{1} }}X_1+ {\boldsymbol {\beta_{2} }}X_2+{\boldsymbol {\beta_{0} }}+{\boldsymbol {\varepsilon }}} \big) $$
#
# b) Explore possible methods of adjusting the learning rate $\alpha$

# %%
from math import exp
# Load the train dataset 
train_data = np.load('utils/assign_1_data_2_train.npy')
# now write the code to find the parameters of the optimization.
learning_rate = 0.005
weights = np.random.rand(3,1)
print weights.shape
def score(data, weights):
	y_hat = np.sum(np.multiply(data[1:,:],weights[1:,:]), axis=0) + weights[0]
	return 1.0/(1.0 + exp(-y_hat))
# Out:
# (3, 1)

# %%
# test on a validation part every 't' iterations to find when you start overfitting.
# t = ?
stopping_criteria = 5
t = 0
flag = 0
previous_s_e = np.array([999.0])
previous_v_e = np.array([999.0])
while True:
	t +=1
	squared_error = 0
	print "Currently in iteration ", t
	#train_data = np.roll(train_data, 60, axis=0)
	for k in range(240):
		data = np.reshape(train_data[k], (3,1))
		#print data.shape
		predicted = score(data, weights)
		error = data[0] - predicted
		squared_error += error**2
		weights[1:,:] = weights[1:,:] + learning_rate*error*predicted*(1-predicted)*data[1:,:]
		weights[0] = weights[0] + learning_rate*error*predicted*(1-predicted)
	#print "Training error is ",squared_error
	validation_error = 0
	for k in range(240,300):
		data = np.reshape(train_data[k], (3,1))
		#print data.shape
		predicted = score(data, weights)
		error = data[0] - predicted
		validation_error += error**2
	if squared_error[0] < previous_s_e[0] and validation_error[0] > previous_v_e[0]:
		stopping_criteria -=1
		flag = 1
		if stopping_criteria == 0:
			break
	if squared_error[0] < previous_s_e[0] and validation_error[0] < previous_v_e[0] and flag == 1:
		stopping_criteria +=1
		if stopping_criteria == 5:
			flag = 0
	previous_v_e = validation_error
	previous_s_e = squared_error
print t
# Now for 't' iterations train on the entire dataset for testing on the test_data
# Out:
# Currently in iteration  1
# Currently in iteration  2
# Currently in iteration  3
# Currently in iteration  4
# Currently in iteration  5
# Currently in iteration  6
# Currently in iteration  7
# Currently in iteration  8
# Currently in iteration  9
# Currently in iteration  10
# Currently in iteration  11
# Currently in iteration  12
# Currently in iteration  13
# Currently in iteration  14
# Currently in iteration  15
# Currently in iteration  16
# Currently in iteration  17
# Currently in iteration  18
# Currently in iteration  19
# Currently in iteration  20
# Currently in iteration  21
# Currently in iteration  22
# Currently in iteration  23
# Currently in iteration  24
# Currently in iteration  25
# Currently in iteration  26
# Currently in iteration  27
# Currently in iteration  28
# Currently in iteration  29
# Currently in iteration  30
# Currently in iteration  31
# Currently in iteration  32
# Currently in iteration  33
# Currently in iteration  34
# Currently in iteration  35
# Currently in iteration  36
# Currently in iteration  37
# Currently in iteration  38
# Currently in iteration  39
# Currently in iteration  40
# Currently in iteration  41
# Currently in iteration  42
# Currently in iteration  43
# Currently in iteration  44
# Currently in iteration  45
# Currently in iteration  46
# Currently in iteration  47
# Currently in iteration  48
# Currently in iteration  49
# Currently in iteration  50
# Currently in iteration  51
# Currently in iteration  52
# Currently in iteration  53
# Currently in iteration  54
# Currently in iteration  55
# Currently in iteration  56
# Currently in iteration  57
# Currently in iteration  58
# Currently in iteration  59
# Currently in iteration  60
# Currently in iteration  61
# Currently in iteration  62
# Currently in iteration  63
# Currently in iteration  64
# Currently in iteration  65
# Currently in iteration  66
# Currently in iteration  67
# Currently in iteration  68
# Currently in iteration  69
# Currently in iteration  70
# Currently in iteration  71
# Currently in iteration  72
# Currently in iteration  73
# Currently in iteration  74
# Currently in iteration  75
# Currently in iteration  76
# Currently in iteration  77
# Currently in iteration  78
# Currently in iteration  79
# Currently in iteration  80
# Currently in iteration  81
# Currently in iteration  82
# Currently in iteration  83
# Currently in iteration  84
# Currently in iteration  85
# Currently in iteration  86
# Currently in iteration  87
# Currently in iteration  88
# Currently in iteration  89
# Currently in iteration  90
# Currently in iteration  91
# Currently in iteration  92
# Currently in iteration  93
# Currently in iteration  94
# Currently in iteration  95
# Currently in iteration  96
# Currently in iteration  97
# Currently in iteration  98
# Currently in iteration  99
# Currently in iteration  100
# Currently in iteration  101
# Currently in iteration  102
# Currently in iteration  103
# Currently in iteration  104
# Currently in iteration  105
# Currently in iteration  106
# Currently in iteration  107
# Currently in iteration  108
# Currently in iteration  109
# Currently in iteration  110
# Currently in iteration  111
# Currently in iteration  112
# Currently in iteration  113
# Currently in iteration  114
# Currently in iteration  115
# Currently in iteration  116
# Currently in iteration  117
# Currently in iteration  118
# Currently in iteration  119
# Currently in iteration  120
# Currently in iteration  121
# Currently in iteration  122
# Currently in iteration  123
# Currently in iteration  124
# Currently in iteration  125
# Currently in iteration  126
# Currently in iteration  127
# Currently in iteration  128
# Currently in iteration  129
# Currently in iteration  130
# Currently in iteration  131
# Currently in iteration  132
# Currently in iteration  133
# Currently in iteration  134
# Currently in iteration  135
# Currently in iteration  136
# Currently in iteration  137
# Currently in iteration  138
# Currently in iteration  139
# Currently in iteration  140
# Currently in iteration  141
# Currently in iteration  142
# Currently in iteration  143
# Currently in iteration  144
# Currently in iteration  145
# Currently in iteration  146
# Currently in iteration  147
# Currently in iteration  148
# Currently in iteration  149
# Currently in iteration  150
# Currently in iteration  151
# Currently in iteration  152
# Currently in iteration  153
# Currently in iteration  154
# Currently in iteration  155
# Currently in iteration  156
# Currently in iteration  157
# Currently in iteration  158
# Currently in iteration  159
# Currently in iteration  160
# Currently in iteration  161
# Currently in iteration  162
# Currently in iteration  163
# Currently in iteration  164
# Currently in iteration  165
# Currently in iteration  166
# Currently in iteration  167
# Currently in iteration  168
# Currently in iteration  169
# Currently in iteration  170
# Currently in iteration  171
# Currently in iteration  172
# Currently in iteration  173
# Currently in iteration  174
# Currently in iteration  175
# Currently in iteration  176
# Currently in iteration  177
# Currently in iteration  178
# Currently in iteration  179
# Currently in iteration  180
# Currently in iteration  181
# Currently in iteration  182
# Currently in iteration  183
# Currently in iteration  184
# Currently in iteration  185
# Currently in iteration  186
# Currently in iteration  187
# Currently in iteration  188
# Currently in iteration  189
# Currently in iteration  190
# Currently in iteration  191
# Currently in iteration  192
# Currently in iteration  193
# Currently in iteration  194
# Currently in iteration  195
# Currently in iteration  196
# Currently in iteration  197
# Currently in iteration  198
# Currently in iteration  199
# Currently in iteration  200
# Currently in iteration  201
# Currently in iteration  202
# Currently in iteration  203
# Currently in iteration  204
# Currently in iteration  205
# Currently in iteration  206
# Currently in iteration  207
# Currently in iteration  208
# Currently in iteration  209
# Currently in iteration  210
# Currently in iteration  211
# Currently in iteration  212
# Currently in iteration  213
# Currently in iteration  214
# Currently in iteration  215
# Currently in iteration  216
# Currently in iteration  217
# Currently in iteration  218
# Currently in iteration  219
# Currently in iteration  220
# Currently in iteration  221
# Currently in iteration  222
# Currently in iteration  223
# Currently in iteration  224
# Currently in iteration  225
# Currently in iteration  226
# Currently in iteration  227
# Currently in iteration  228
# Currently in iteration  229
# Currently in iteration  230
# Currently in iteration  231
# Currently in iteration  232
# Currently in iteration  233
# Currently in iteration  234
# Currently in iteration  235
# Currently in iteration  236
# Currently in iteration  237
# Currently in iteration  238
# Currently in iteration  239
# Currently in iteration  240
# Currently in iteration  241
# Currently in iteration  242
# Currently in iteration  243
# Currently in iteration  244
# Currently in iteration  245
# Currently in iteration  246
# Currently in iteration  247
# Currently in iteration  248
# Currently in iteration  249
# Currently in iteration  250
# Currently in iteration  251
# Currently in iteration  252
# Currently in iteration  253
# Currently in iteration  254
# Currently in iteration  255
# Currently in iteration  256
# Currently in iteration  257
# Currently in iteration  258
# Currently in iteration  259
# Currently in iteration  260
# Currently in iteration  261
# Currently in iteration  262
# Currently in iteration  263
# Currently in iteration  264
# Currently in iteration  265
# Currently in iteration  266
# Currently in iteration  267
# Currently in iteration  268
# Currently in iteration  269
# Currently in iteration  270
# Currently in iteration  271
# Currently in iteration  272
# Currently in iteration  273
# Currently in iteration  274
# Currently in iteration  275
# Currently in iteration  276
# Currently in iteration  277
# Currently in iteration  278
# Currently in iteration  279
# Currently in iteration  280
# Currently in iteration  281
# Currently in iteration  282
# Currently in iteration  283
# Currently in iteration  284
# Currently in iteration  285
# Currently in iteration  286
# Currently in iteration  287
# Currently in iteration  288
# Currently in iteration  289
# Currently in iteration  290
# Currently in iteration  291
# Currently in iteration  292
# Currently in iteration  293
# Currently in iteration  294
# Currently in iteration  295
# Currently in iteration  296
# Currently in iteration  297
# Currently in iteration  298
# Currently in iteration  299
# Currently in iteration  300
# Currently in iteration  301
# Currently in iteration  302
# Currently in iteration  303
# Currently in iteration  304
# Currently in iteration  305
# Currently in iteration  306
# Currently in iteration  307
# Currently in iteration  308
# Currently in iteration  309
# Currently in iteration  310
# Currently in iteration  311
# Currently in iteration  312
# Currently in iteration  313
# Currently in iteration  314
# Currently in iteration  315
# Currently in iteration  316
# Currently in iteration  317
# Currently in iteration  318
# Currently in iteration  319
# Currently in iteration  320
# Currently in iteration  321
# Currently in iteration  322
# Currently in iteration  323
# Currently in iteration  324
# Currently in iteration  325
# Currently in iteration  326
# Currently in iteration  327
# Currently in iteration  328
# Currently in iteration  329
# Currently in iteration  330
# Currently in iteration  331
# Currently in iteration  332
# Currently in iteration  333
# Currently in iteration  334
# Currently in iteration  335
# Currently in iteration  336
# Currently in iteration  337
# Currently in iteration  338
# Currently in iteration  339
# Currently in iteration  340
# Currently in iteration  341
# Currently in iteration  342
# Currently in iteration  343
# Currently in iteration  344
# Currently in iteration  345
# Currently in iteration  346
# Currently in iteration  347
# Currently in iteration  348
# Currently in iteration  349
# Currently in iteration  350
# Currently in iteration  351
# Currently in iteration  352
# Currently in iteration  353
# Currently in iteration  354
# Currently in iteration  355
# Currently in iteration  356
# Currently in iteration  357
# Currently in iteration  358
# Currently in iteration  359
# Currently in iteration  360
# Currently in iteration  361
# Currently in iteration  362
# Currently in iteration  363
# Currently in iteration  364
# Currently in iteration  365
# Currently in iteration  366
# Currently in iteration  367
# Currently in iteration  368
# Currently in iteration  369
# Currently in iteration  370
# Currently in iteration  371
# Currently in iteration  372
# Currently in iteration  373
# Currently in iteration  374
# Currently in iteration  375
# Currently in iteration  376
# Currently in iteration  377
# Currently in iteration  378
# Currently in iteration  379
# Currently in iteration  380
# Currently in iteration  381
# Currently in iteration  382
# Currently in iteration  383
# Currently in iteration  384
# Currently in iteration  385
# Currently in iteration  386
# Currently in iteration  387
# Currently in iteration  388
# Currently in iteration  389
# Currently in iteration  390
# Currently in iteration  391
# Currently in iteration  392
# Currently in iteration  393
# Currently in iteration  394
# Currently in iteration  395
# Currently in iteration  396
# Currently in iteration  397
# Currently in iteration  398
# Currently in iteration  399
# Currently in iteration  400
# Currently in iteration  401
# Currently in iteration  402
# Currently in iteration  403
# Currently in iteration  404
# Currently in iteration  405
# Currently in iteration  406
# Currently in iteration  407
# Currently in iteration  408
# Currently in iteration  409
# Currently in iteration  410
# Currently in iteration  411
# Currently in iteration  412
# Currently in iteration  413
# Currently in iteration  414
# Currently in iteration  415
# Currently in iteration  416
# Currently in iteration  417
# Currently in iteration  418
# Currently in iteration  419
# Currently in iteration  420
# Currently in iteration  421
# Currently in iteration  422
# Currently in iteration  423
# Currently in iteration  424
# Currently in iteration  425
# Currently in iteration  426
# Currently in iteration  427
# Currently in iteration  428
# Currently in iteration  429
# Currently in iteration  430
# Currently in iteration  431
# Currently in iteration  432
# Currently in iteration  433
# Currently in iteration  434
# Currently in iteration  435
# Currently in iteration  436
# Currently in iteration  437
# Currently in iteration  438
# Currently in iteration  439
# Currently in iteration  440
# Currently in iteration  441
# Currently in iteration  442
# Currently in iteration  443
# Currently in iteration  444
# Currently in iteration  445
# Currently in iteration  446
# Currently in iteration  447
# Currently in iteration  448
# Currently in iteration  449
# Currently in iteration  450
# Currently in iteration  451
# Currently in iteration  452
# Currently in iteration  453
# Currently in iteration  454
# Currently in iteration  455
# Currently in iteration  456
# Currently in iteration  457
# Currently in iteration  458
# Currently in iteration  459
# Currently in iteration  460
# Currently in iteration  461
# Currently in iteration  462
# Currently in iteration  463
# Currently in iteration  464
# Currently in iteration  465
# Currently in iteration  466
# Currently in iteration  467
# Currently in iteration  468
# Currently in iteration  469
# Currently in iteration  470
# Currently in iteration  471
# Currently in iteration  472
# Currently in iteration  473
# Currently in iteration  474
# Currently in iteration  475
# Currently in iteration  476
# Currently in iteration  477
# Currently in iteration  478
# Currently in iteration  479
# Currently in iteration  480
# Currently in iteration  481
# Currently in iteration  482
# Currently in iteration  483
# Currently in iteration  484
# Currently in iteration  485
# Currently in iteration  486
# Currently in iteration  487
# Currently in iteration  488
# Currently in iteration  489
# Currently in iteration  490
# Currently in iteration  491
# Currently in iteration  492
# Currently in iteration  493
# Currently in iteration  494
# Currently in iteration  495
# Currently in iteration  496
# Currently in iteration  497
# Currently in iteration  498
# Currently in iteration  499
# Currently in iteration  500
# Currently in iteration  501
# Currently in iteration  502
# Currently in iteration  503
# Currently in iteration  504
# Currently in iteration  505
# Currently in iteration  506
# Currently in iteration  507
# Currently in iteration  508
# Currently in iteration  509
# Currently in iteration  510
# Currently in iteration  511
# Currently in iteration  512
# Currently in iteration  513
# Currently in iteration  514
# Currently in iteration  515
# Currently in iteration  516
# Currently in iteration  517
# Currently in iteration  518
# Currently in iteration  519
# Currently in iteration  520
# Currently in iteration  521
# Currently in iteration  522
# Currently in iteration  523
# Currently in iteration  524
# Currently in iteration  525
# Currently in iteration  526
# Currently in iteration  527
# Currently in iteration  528
# Currently in iteration  529
# Currently in iteration  530
# Currently in iteration  531
# Currently in iteration  532
# Currently in iteration  533
# Currently in iteration  534
# Currently in iteration  535
# Currently in iteration  536
# Currently in iteration  537
# Currently in iteration  538
# Currently in iteration  539
# Currently in iteration  540
# Currently in iteration  541
# Currently in iteration  542
# Currently in iteration  543
# Currently in iteration  544
# Currently in iteration  545
# Currently in iteration  546
# Currently in iteration  547
# Currently in iteration  548
# Currently in iteration  549
# Currently in iteration  550
# Currently in iteration  551
# Currently in iteration  552
# Currently in iteration  553
# Currently in iteration  554
# Currently in iteration  555
# Currently in iteration  556
# Currently in iteration  557
# Currently in iteration  558
# Currently in iteration  559
# Currently in iteration  560
# Currently in iteration  561
# Currently in iteration  562
# Currently in iteration  563
# Currently in iteration  564
# Currently in iteration  565
# Currently in iteration  566
# Currently in iteration  567
# Currently in iteration  568
# Currently in iteration  569
# Currently in iteration  570
# Currently in iteration  571
# Currently in iteration  572
# Currently in iteration  573
# Currently in iteration  574
# Currently in iteration  575
# Currently in iteration  576
# Currently in iteration  577
# Currently in iteration  578
# Currently in iteration  579
# Currently in iteration  580
# Currently in iteration  581
# Currently in iteration  582
# Currently in iteration  583
# Currently in iteration  584
# Currently in iteration  585
# Currently in iteration  586
# Currently in iteration  587
# Currently in iteration  588
# Currently in iteration  589
# Currently in iteration  590
# Currently in iteration  591
# Currently in iteration  592
# Currently in iteration  593
# Currently in iteration  594
# Currently in iteration  595
# Currently in iteration  596
# Currently in iteration  597
# Currently in iteration  598
# Currently in iteration  599
# Currently in iteration  600
# Currently in iteration  601
# Currently in iteration  602
# Currently in iteration  603
# Currently in iteration  604
# Currently in iteration  605
# Currently in iteration  606
# Currently in iteration  607
# Currently in iteration  608
# Currently in iteration  609
# Currently in iteration  610
# Currently in iteration  611
# Currently in iteration  612
# Currently in iteration  613
# Currently in iteration  614
# Currently in iteration  615
# Currently in iteration  616
# Currently in iteration  617
# Currently in iteration  618
# Currently in iteration  619
# Currently in iteration  620
# Currently in iteration  621
# Currently in iteration  622
# Currently in iteration  623
# Currently in iteration  624
# Currently in iteration  625
# Currently in iteration  626
# Currently in iteration  627
# Currently in iteration  628
# Currently in iteration  629
# Currently in iteration  630
# Currently in iteration  631
# Currently in iteration  632
# Currently in iteration  633
# Currently in iteration  634
# Currently in iteration  635
# Currently in iteration  636
# Currently in iteration  637
# Currently in iteration  638
# Currently in iteration  639
# Currently in iteration  640
# Currently in iteration  641
# Currently in iteration  642
# Currently in iteration  643
# Currently in iteration  644
# Currently in iteration  645
# Currently in iteration  646
# Currently in iteration  647
# Currently in iteration  648
# Currently in iteration  649
# Currently in iteration  650
# Currently in iteration  651
# Currently in iteration  652
# Currently in iteration  653
# Currently in iteration  654
# Currently in iteration  655
# Currently in iteration  656
# Currently in iteration  657
# Currently in iteration  658
# Currently in iteration  659
# Currently in iteration  660
# Currently in iteration  661
# Currently in iteration  662
# Currently in iteration  663
# Currently in iteration  664
# Currently in iteration  665
# Currently in iteration  666
# Currently in iteration  667
# Currently in iteration  668
# Currently in iteration  669
# Currently in iteration  670
# Currently in iteration  671
# Currently in iteration  672
# Currently in iteration  673
# Currently in iteration  674
# Currently in iteration  675
# Currently in iteration  676
# Currently in iteration  677
# Currently in iteration  678
# Currently in iteration  679
# Currently in iteration  680
# Currently in iteration  681
# Currently in iteration  682
# Currently in iteration  683
# Currently in iteration  684
# Currently in iteration  685
# Currently in iteration  686
# Currently in iteration  687
# Currently in iteration  688
# Currently in iteration  689
# Currently in iteration  690
# Currently in iteration  691
# Currently in iteration  692
# Currently in iteration  693
# Currently in iteration  694
# Currently in iteration  695
# Currently in iteration  696
# Currently in iteration  697
# Currently in iteration  698
# Currently in iteration  699
# Currently in iteration  700
# Currently in iteration  701
# Currently in iteration  702
# Currently in iteration  703
# Currently in iteration  704
# Currently in iteration  705
# Currently in iteration  706
# Currently in iteration  707
# Currently in iteration  708
# Currently in iteration  709
# Currently in iteration  710
# Currently in iteration  711
# Currently in iteration  712
# Currently in iteration  713
# Currently in iteration  714
# Currently in iteration  715
# Currently in iteration  716
# Currently in iteration  717
# Currently in iteration  718
# Currently in iteration  719
# Currently in iteration  720
# Currently in iteration  721
# Currently in iteration  722
# Currently in iteration  723
# Currently in iteration  724
# Currently in iteration  725
# Currently in iteration  726
# Currently in iteration  727
# Currently in iteration  728
# Currently in iteration  729
# Currently in iteration  730
# Currently in iteration  731
# Currently in iteration  732
# Currently in iteration  733
# Currently in iteration  734
# Currently in iteration  735
# Currently in iteration  736
# Currently in iteration  737
# Currently in iteration  738
# Currently in iteration  739
# Currently in iteration  740
# Currently in iteration  741
# Currently in iteration  742
# Currently in iteration  743
# Currently in iteration  744
# Currently in iteration  745
# Currently in iteration  746
# Currently in iteration  747
# Currently in iteration  748
# Currently in iteration  749
# Currently in iteration  750
# Currently in iteration  751
# Currently in iteration  752
# Currently in iteration  753
# Currently in iteration  754
# Currently in iteration  755
# Currently in iteration  756
# Currently in iteration  757
# Currently in iteration  758
# Currently in iteration  759
# Currently in iteration  760
# Currently in iteration  761
# Currently in iteration  762
# Currently in iteration  763
# Currently in iteration  764
# Currently in iteration  765
# Currently in iteration  766
# Currently in iteration  767
# Currently in iteration  768
# Currently in iteration  769
# Currently in iteration  770
# Currently in iteration  771
# Currently in iteration  772
# Currently in iteration  773
# Currently in iteration  774
# Currently in iteration  775
# Currently in iteration  776
# Currently in iteration  777
# Currently in iteration  778
# Currently in iteration  779
# Currently in iteration  780
# Currently in iteration  781
# Currently in iteration  782
# Currently in iteration  783
# Currently in iteration  784
# Currently in iteration  785
# Currently in iteration  786
# Currently in iteration  787
# Currently in iteration  788
# Currently in iteration  789
# Currently in iteration  790
# Currently in iteration  791
# Currently in iteration  792
# Currently in iteration  793
# Currently in iteration  794
# Currently in iteration  795
# Currently in iteration  796
# Currently in iteration  797
# Currently in iteration  798
# Currently in iteration  799
# Currently in iteration  800
# Currently in iteration  801
# Currently in iteration  802
# Currently in iteration  803
# Currently in iteration  804
# Currently in iteration  805
# Currently in iteration  806
# Currently in iteration  807
# Currently in iteration  808
# Currently in iteration  809
# Currently in iteration  810
# Currently in iteration  811
# Currently in iteration  812
# Currently in iteration  813
# Currently in iteration  814
# Currently in iteration  815
# Currently in iteration  816
# Currently in iteration  817
# Currently in iteration  818
# Currently in iteration  819
# Currently in iteration  820
# Currently in iteration  821
# Currently in iteration  822
# Currently in iteration  823
# Currently in iteration  824
# Currently in iteration  825
# Currently in iteration  826
# Currently in iteration  827
# Currently in iteration  828
# Currently in iteration  829
# Currently in iteration  830
# Currently in iteration  831
# Currently in iteration  832
# Currently in iteration  833
# Currently in iteration  834
# Currently in iteration  835
# Currently in iteration  836
# Currently in iteration  837
# Currently in iteration  838
# Currently in iteration  839
# Currently in iteration  840
# Currently in iteration  841
# Currently in iteration  842
# Currently in iteration  843
# Currently in iteration  844
# Currently in iteration  845
# Currently in iteration  846
# Currently in iteration  847
# Currently in iteration  848
# Currently in iteration  849
# Currently in iteration  850
# Currently in iteration  851
# Currently in iteration  852
# Currently in iteration  853
# Currently in iteration  854
# Currently in iteration  855
# Currently in iteration  856
# Currently in iteration  857
# Currently in iteration  858
# Currently in iteration  859
# Currently in iteration  860
# Currently in iteration  861
# Currently in iteration  862
# Currently in iteration  863
# Currently in iteration  864
# Currently in iteration  865
# Currently in iteration  866
# Currently in iteration  867
# Currently in iteration  868
# Currently in iteration  869
# Currently in iteration  870
# Currently in iteration  871
# Currently in iteration  872
# Currently in iteration  873
# Currently in iteration  874
# Currently in iteration  875
# Currently in iteration  876
# Currently in iteration  877
# Currently in iteration  878
# Currently in iteration  879
# Currently in iteration  880
# Currently in iteration  881
# Currently in iteration  882
# Currently in iteration  883
# Currently in iteration  884
# Currently in iteration  885
# Currently in iteration  886
# Currently in iteration  887
# Currently in iteration  888
# Currently in iteration  889
# Currently in iteration  890
# Currently in iteration  891
# Currently in iteration  892
# Currently in iteration  893
# Currently in iteration  894
# Currently in iteration  895
# Currently in iteration  896
# Currently in iteration  897
# Currently in iteration  898
# Currently in iteration  899
# Currently in iteration  900
# Currently in iteration  901
# Currently in iteration  902
# Currently in iteration  903
# Currently in iteration  904
# Currently in iteration  905
# Currently in iteration  906
# Currently in iteration  907
# Currently in iteration  908
# Currently in iteration  909
# Currently in iteration  910
# Currently in iteration  911
# Currently in iteration  912
# Currently in iteration  913
# Currently in iteration  914
# Currently in iteration  915
# Currently in iteration  916
# Currently in iteration  917
# Currently in iteration  918
# Currently in iteration  919
# Currently in iteration  920
# Currently in iteration  921
# Currently in iteration  922
# Currently in iteration  923
# Currently in iteration  924
# Currently in iteration  925
# Currently in iteration  926
# Currently in iteration  927
# Currently in iteration  928
# Currently in iteration  929
# Currently in iteration  930
# Currently in iteration  931
# Currently in iteration  932
# Currently in iteration  933
# Currently in iteration  934
# Currently in iteration  935
# Currently in iteration  936
# Currently in iteration  937
# Currently in iteration  938
# Currently in iteration  939
# Currently in iteration  940
# Currently in iteration  941
# Currently in iteration  942
# Currently in iteration  943
# Currently in iteration  944
# Currently in iteration  945
# Currently in iteration  946
# Currently in iteration  947
# Currently in iteration  948
# Currently in iteration  949
# Currently in iteration  950
# Currently in iteration  951
# Currently in iteration  952
# Currently in iteration  953
# Currently in iteration  954
# Currently in iteration  955
# Currently in iteration  956
# Currently in iteration  957
# Currently in iteration  958
# Currently in iteration  959
# Currently in iteration  960
# Currently in iteration  961
# Currently in iteration  962
# Currently in iteration  963
# Currently in iteration  964
# Currently in iteration  965
# Currently in iteration  966
# Currently in iteration  967
# Currently in iteration  968
# Currently in iteration  969
# Currently in iteration  970
# Currently in iteration  971
# Currently in iteration  972
# Currently in iteration  973
# Currently in iteration  974
# Currently in iteration  975
# Currently in iteration  976
# Currently in iteration  977
# Currently in iteration  978
# Currently in iteration  979
# Currently in iteration  980
# Currently in iteration  981
# Currently in iteration  982
# Currently in iteration  983
# Currently in iteration  984
# Currently in iteration  985
# Currently in iteration  986
# Currently in iteration  987
# Currently in iteration  988
# Currently in iteration  989
# Currently in iteration  990
# Currently in iteration  991
# Currently in iteration  992
# Currently in iteration  993
# Currently in iteration  994
# Currently in iteration  995
# Currently in iteration  996
# Currently in iteration  997
# Currently in iteration  998
# Currently in iteration  999
# Currently in iteration  1000
# Currently in iteration  1001
# Currently in iteration  1002
# Currently in iteration  1003
# Currently in iteration  1004
# Currently in iteration  1005
# Currently in iteration  1006
# Currently in iteration  1007
# Currently in iteration  1008
# Currently in iteration  1009
# Currently in iteration  1010
# Currently in iteration  1011
# Currently in iteration  1012
# Currently in iteration  1013
# Currently in iteration  1014
# Currently in iteration  1015
# Currently in iteration  1016
# Currently in iteration  1017
# Currently in iteration  1018
# Currently in iteration  1019
# Currently in iteration  1020
# Currently in iteration  1021
# Currently in iteration  1022
# Currently in iteration  1023
# Currently in iteration  1024
# Currently in iteration  1025
# Currently in iteration  1026
# Currently in iteration  1027
# Currently in iteration  1028
# Currently in iteration  1029
# Currently in iteration  1030
# Currently in iteration  1031
# Currently in iteration  1032
# Currently in iteration  1033
# Currently in iteration  1034
# Currently in iteration  1035
# Currently in iteration  1036
# Currently in iteration  1037
# Currently in iteration  1038
# Currently in iteration  1039
# Currently in iteration  1040
# Currently in iteration  1041
# Currently in iteration  1042
# Currently in iteration  1043
# Currently in iteration  1044
# Currently in iteration  1045
# Currently in iteration  1046
# Currently in iteration  1047
# Currently in iteration  1048
# Currently in iteration  1049
# Currently in iteration  1050
# Currently in iteration  1051
# Currently in iteration  1052
# Currently in iteration  1053
# Currently in iteration  1054
# Currently in iteration  1055
# Currently in iteration  1056
# Currently in iteration  1057
# Currently in iteration  1058
# Currently in iteration  1059
# Currently in iteration  1060
# Currently in iteration  1061
# Currently in iteration  1062
# Currently in iteration  1063
# Currently in iteration  1064
# Currently in iteration  1065
# Currently in iteration  1066
# Currently in iteration  1067
# Currently in iteration  1068
# Currently in iteration  1069
# Currently in iteration  1070
# Currently in iteration  1071
# Currently in iteration  1072
# Currently in iteration  1073
# Currently in iteration  1074
# Currently in iteration  1075
# Currently in iteration  1076
# Currently in iteration  1077
# Currently in iteration  1078
# Currently in iteration  1079
# Currently in iteration  1080
# Currently in iteration  1081
# Currently in iteration  1082
# Currently in iteration  1083
# Currently in iteration  1084
# Currently in iteration  1085
# Currently in iteration  1086
# Currently in iteration  1087
# Currently in iteration  1088
# Currently in iteration  1089
# Currently in iteration  1090
# Currently in iteration  1091
# Currently in iteration  1092
# Currently in iteration  1093
# Currently in iteration  1094
# Currently in iteration  1095
# Currently in iteration  1096
# Currently in iteration  1097
# Currently in iteration  1098
# Currently in iteration  1099
# Currently in iteration  1100
# Currently in iteration  1101
# Currently in iteration  1102
# Currently in iteration  1103
# Currently in iteration  1104
# Currently in iteration  1105
# Currently in iteration  1106
# Currently in iteration  1107
# Currently in iteration  1108
# Currently in iteration  1109
# Currently in iteration  1110
# Currently in iteration  1111
# Currently in iteration  1112
# Currently in iteration  1113
# Currently in iteration  1114
# Currently in iteration  1115
# Currently in iteration  1116
# Currently in iteration  1117
# Currently in iteration  1118
# Currently in iteration  1119
# Currently in iteration  1120
# Currently in iteration  1121
# Currently in iteration  1122
# Currently in iteration  1123
# Currently in iteration  1124
# Currently in iteration  1125
# Currently in iteration  1126
# Currently in iteration  1127
# Currently in iteration  1128
# Currently in iteration  1129
# Currently in iteration  1130
# Currently in iteration  1131
# Currently in iteration  1132
# Currently in iteration  1133
# Currently in iteration  1134
# Currently in iteration  1135
# Currently in iteration  1136
# Currently in iteration  1137
# Currently in iteration  1138
# Currently in iteration  1139
# Currently in iteration  1140
# Currently in iteration  1141
# Currently in iteration  1142
# Currently in iteration  1143
# Currently in iteration  1144
# Currently in iteration  1145
# Currently in iteration  1146
# Currently in iteration  1147
# Currently in iteration  1148
# Currently in iteration  1149
# Currently in iteration  1150
# Currently in iteration  1151
# Currently in iteration  1152
# Currently in iteration  1153
# Currently in iteration  1154
# Currently in iteration  1155
# Currently in iteration  1156
# Currently in iteration  1157
# Currently in iteration  1158
# Currently in iteration  1159
# Currently in iteration  1160
# Currently in iteration  1161
# Currently in iteration  1162
# Currently in iteration  1163
# Currently in iteration  1164
# Currently in iteration  1165
# Currently in iteration  1166
# Currently in iteration  1167
# Currently in iteration  1168
# Currently in iteration  1169
# Currently in iteration  1170
# Currently in iteration  1171
# Currently in iteration  1172
# Currently in iteration  1173
# Currently in iteration  1174
# Currently in iteration  1175
# Currently in iteration  1176
# Currently in iteration  1177
# Currently in iteration  1178
# Currently in iteration  1179
# Currently in iteration  1180
# Currently in iteration  1181
# Currently in iteration  1182
# Currently in iteration  1183
# Currently in iteration  1184
# Currently in iteration  1185
# Currently in iteration  1186
# Currently in iteration  1187
# Currently in iteration  1188
# Currently in iteration  1189
# Currently in iteration  1190
# Currently in iteration  1191
# Currently in iteration  1192
# Currently in iteration  1193
# Currently in iteration  1194
# Currently in iteration  1195
# Currently in iteration  1196
# Currently in iteration  1197
# Currently in iteration  1198
# Currently in iteration  1199
# Currently in iteration  1200
# Currently in iteration  1201
# Currently in iteration  1202
# Currently in iteration  1203
# Currently in iteration  1204
# Currently in iteration  1205
# Currently in iteration  1206
# Currently in iteration  1207
# Currently in iteration  1208
# Currently in iteration  1209
# Currently in iteration  1210
# Currently in iteration  1211
# Currently in iteration  1212
# Currently in iteration  1213
# Currently in iteration  1214
# Currently in iteration  1215
# Currently in iteration  1216
# Currently in iteration  1217
# Currently in iteration  1218
# Currently in iteration  1219
# Currently in iteration  1220
# Currently in iteration  1221
# Currently in iteration  1222
# Currently in iteration  1223
# Currently in iteration  1224
# Currently in iteration  1225
# Currently in iteration  1226
# Currently in iteration  1227
# Currently in iteration  1228
# Currently in iteration  1229
# Currently in iteration  1230
# Currently in iteration  1231
# Currently in iteration  1232
# Currently in iteration  1233
# Currently in iteration  1234
# Currently in iteration  1235
# Currently in iteration  1236
# Currently in iteration  1237
# Currently in iteration  1238
# Currently in iteration  1239
# Currently in iteration  1240
# Currently in iteration  1241
# Currently in iteration  1242
# Currently in iteration  1243
# Currently in iteration  1244
# Currently in iteration  1245
# Currently in iteration  1246
# Currently in iteration  1247
# Currently in iteration  1248
# Currently in iteration  1249
# Currently in iteration  1250
# Currently in iteration  1251
# Currently in iteration  1252
# Currently in iteration  1253
# Currently in iteration  1254
# Currently in iteration  1255
# Currently in iteration  1256
# Currently in iteration  1257
# Currently in iteration  1258
# Currently in iteration  1259
# Currently in iteration  1260
# Currently in iteration  1261
# Currently in iteration  1262
# Currently in iteration  1263
# Currently in iteration  1264
# Currently in iteration  1265
# Currently in iteration  1266
# Currently in iteration  1267
# Currently in iteration  1268
# Currently in iteration  1269
# Currently in iteration  1270
# Currently in iteration  1271
# Currently in iteration  1272
# Currently in iteration  1273
# Currently in iteration  1274
# Currently in iteration  1275
# Currently in iteration  1276
# Currently in iteration  1277
# Currently in iteration  1278
# Currently in iteration  1279
# Currently in iteration  1280
# Currently in iteration  1281
# Currently in iteration  1282
# Currently in iteration  1283
# Currently in iteration  1284
# Currently in iteration  1285
# Currently in iteration  1286
# Currently in iteration  1287
# Currently in iteration  1288
# Currently in iteration  1289
# Currently in iteration  1290
# Currently in iteration  1291
# Currently in iteration  1292
# Currently in iteration  1293
# Currently in iteration  1294
# Currently in iteration  1295
# Currently in iteration  1296
# Currently in iteration  1297
# Currently in iteration  1298
# Currently in iteration  1299
# Currently in iteration  1300
# Currently in iteration  1301
# Currently in iteration  1302
# Currently in iteration  1303
# Currently in iteration  1304
# Currently in iteration  1305
# Currently in iteration  1306
# Currently in iteration  1307
# Currently in iteration  1308
# Currently in iteration  1309
# Currently in iteration  1310
# Currently in iteration  1311
# Currently in iteration  1312
# Currently in iteration  1313
# Currently in iteration  1314
# Currently in iteration  1315
# Currently in iteration  1316
# Currently in iteration  1317
# Currently in iteration  1318
# Currently in iteration  1319
# Currently in iteration  1320
# Currently in iteration  1321
# Currently in iteration  1322
# Currently in iteration  1323
# Currently in iteration  1324
# Currently in iteration  1325
# Currently in iteration  1326
# Currently in iteration  1327
# Currently in iteration  1328
# Currently in iteration  1329
# Currently in iteration  1330
# Currently in iteration  1331
# Currently in iteration  1332
# Currently in iteration  1333
# Currently in iteration  1334
# Currently in iteration  1335
# Currently in iteration  1336
# Currently in iteration  1337
# Currently in iteration  1338
# Currently in iteration  1339
# Currently in iteration  1340
# Currently in iteration  1341
# Currently in iteration  1342
# Currently in iteration  1343
# Currently in iteration  1344
# Currently in iteration  1345
# Currently in iteration  1346
# Currently in iteration  1347
# Currently in iteration  1348
# Currently in iteration  1349
# Currently in iteration  1350
# Currently in iteration  1351
# Currently in iteration  1352
# Currently in iteration  1353
# Currently in iteration  1354
# Currently in iteration  1355
# Currently in iteration  1356
# Currently in iteration  1357
# Currently in iteration  1358
# Currently in iteration  1359
# Currently in iteration  1360
# Currently in iteration  1361
# Currently in iteration  1362
# Currently in iteration  1363
# Currently in iteration  1364
# Currently in iteration  1365
# Currently in iteration  1366
# Currently in iteration  1367
# Currently in iteration  1368
# Currently in iteration  1369
# Currently in iteration  1370
# Currently in iteration  1371
# Currently in iteration  1372
# Currently in iteration  1373
# Currently in iteration  1374
# Currently in iteration  1375
# Currently in iteration  1376
# Currently in iteration  1377
# Currently in iteration  1378
# Currently in iteration  1379
# Currently in iteration  1380
# Currently in iteration  1381
# Currently in iteration  1382
# Currently in iteration  1383
# Currently in iteration  1384
# Currently in iteration  1385
# Currently in iteration  1386
# Currently in iteration  1387
# Currently in iteration  1388
# Currently in iteration  1389
# Currently in iteration  1390
# Currently in iteration  1391
# Currently in iteration  1392
# Currently in iteration  1393
# Currently in iteration  1394
# Currently in iteration  1395
# Currently in iteration  1396
# Currently in iteration  1397
# Currently in iteration  1398
# Currently in iteration  1399
# Currently in iteration  1400
# Currently in iteration  1401
# Currently in iteration  1402
# Currently in iteration  1403
# Currently in iteration  1404
# Currently in iteration  1405
# Currently in iteration  1406
# Currently in iteration  1407
# Currently in iteration  1408
# Currently in iteration  1409
# Currently in iteration  1410
# Currently in iteration  1411
# Currently in iteration  1412
# Currently in iteration  1413
# Currently in iteration  1414
# Currently in iteration  1415
# Currently in iteration  1416
# Currently in iteration  1417
# Currently in iteration  1418
# Currently in iteration  1419
# Currently in iteration  1420
# Currently in iteration  1421
# Currently in iteration  1422
# Currently in iteration  1423
# Currently in iteration  1424
# Currently in iteration  1425
# Currently in iteration  1426
# Currently in iteration  1427
# Currently in iteration  1428
# Currently in iteration  1429
# Currently in iteration  1430
# Currently in iteration  1431
# Currently in iteration  1432
# Currently in iteration  1433
# Currently in iteration  1434
# Currently in iteration  1435
# Currently in iteration  1436
# Currently in iteration  1437
# Currently in iteration  1438
# Currently in iteration  1439
# Currently in iteration  1440
# Currently in iteration  1441
# Currently in iteration  1442
# Currently in iteration  1443
# Currently in iteration  1444
# Currently in iteration  1445
# Currently in iteration  1446
# Currently in iteration  1447
# Currently in iteration  1448
# Currently in iteration  1449
# Currently in iteration  1450
# Currently in iteration  1451
# Currently in iteration  1452
# Currently in iteration  1453
# Currently in iteration  1454
# Currently in iteration  1455
# Currently in iteration  1456
# Currently in iteration  1457
# Currently in iteration  1458
# Currently in iteration  1459
# Currently in iteration  1460
# Currently in iteration  1461
# Currently in iteration  1462
# Currently in iteration  1463
# Currently in iteration  1464
# Currently in iteration  1465
# Currently in iteration  1466
# Currently in iteration  1467
# Currently in iteration  1468
# Currently in iteration  1469
# Currently in iteration  1470
# Currently in iteration  1471
# Currently in iteration  1472
# Currently in iteration  1473
# Currently in iteration  1474
# Currently in iteration  1475
# Currently in iteration  1476
# Currently in iteration  1477
# Currently in iteration  1478
# Currently in iteration  1479
# Currently in iteration  1480
# Currently in iteration  1481
# Currently in iteration  1482
# Currently in iteration  1483
# Currently in iteration  1484
# Currently in iteration  1485
# Currently in iteration  1486
# Currently in iteration  1487
# Currently in iteration  1488
# Currently in iteration  1489
# Currently in iteration  1490
# Currently in iteration  1491
# Currently in iteration  1492
# Currently in iteration  1493
# Currently in iteration  1494
# Currently in iteration  1495
# Currently in iteration  1496
# Currently in iteration  1497
# Currently in iteration  1498
# Currently in iteration  1499
# Currently in iteration  1500
# Currently in iteration  1501
# Currently in iteration  1502
# Currently in iteration  1503
# Currently in iteration  1504
# Currently in iteration  1505
# Currently in iteration  1506
# Currently in iteration  1507
# Currently in iteration  1508
# Currently in iteration  1509
# Currently in iteration  1510
# Currently in iteration  1511
# Currently in iteration  1512
# Currently in iteration  1513
# Currently in iteration  1514
# Currently in iteration  1515
# Currently in iteration  1516
# Currently in iteration  1517
# Currently in iteration  1518
# Currently in iteration  1519
# Currently in iteration  1520
# Currently in iteration  1521
# Currently in iteration  1522
# Currently in iteration  1523
# Currently in iteration  1524
# Currently in iteration  1525
# Currently in iteration  1526
# Currently in iteration  1527
# Currently in iteration  1528
# Currently in iteration  1529
# Currently in iteration  1530
# Currently in iteration  1531
# Currently in iteration  1532
# Currently in iteration  1533
# Currently in iteration  1534
# Currently in iteration  1535
# Currently in iteration  1536
# Currently in iteration  1537
# Currently in iteration  1538
# Currently in iteration  1539
# Currently in iteration  1540
# Currently in iteration  1541
# Currently in iteration  1542
# Currently in iteration  1543
# Currently in iteration  1544
# Currently in iteration  1545
# Currently in iteration  1546
# Currently in iteration  1547
# Currently in iteration  1548
# Currently in iteration  1549
# Currently in iteration  1550
# Currently in iteration  1551
# Currently in iteration  1552
# Currently in iteration  1553
# Currently in iteration  1554
# Currently in iteration  1555
# Currently in iteration  1556
# Currently in iteration  1557
# Currently in iteration  1558
# Currently in iteration  1559
# Currently in iteration  1560
# Currently in iteration  1561
# Currently in iteration  1562
# Currently in iteration  1563
# Currently in iteration  1564
# Currently in iteration  1565
# Currently in iteration  1566
# Currently in iteration  1567
# Currently in iteration  1568
# Currently in iteration  1569
# Currently in iteration  1570
# Currently in iteration  1571
# Currently in iteration  1572
# Currently in iteration  1573
# Currently in iteration  1574
# Currently in iteration  1575
# Currently in iteration  1576
# Currently in iteration  1577
# Currently in iteration  1578
# Currently in iteration  1579
# Currently in iteration  1580
# Currently in iteration  1581
# Currently in iteration  1582
# Currently in iteration  1583
# Currently in iteration  1584
# Currently in iteration  1585
# Currently in iteration  1586
# Currently in iteration  1587
# Currently in iteration  1588
# Currently in iteration  1589
# Currently in iteration  1590
# Currently in iteration  1591
# Currently in iteration  1592
# Currently in iteration  1593
# Currently in iteration  1594
# Currently in iteration  1595
# Currently in iteration  1596
# Currently in iteration  1597
# Currently in iteration  1598
# Currently in iteration  1599
# Currently in iteration  1600
# Currently in iteration  1601
# Currently in iteration  1602
# Currently in iteration  1603
# Currently in iteration  1604
# Currently in iteration  1605
# Currently in iteration  1606
# Currently in iteration  1607
# Currently in iteration  1608
# Currently in iteration  1609
# Currently in iteration  1610
# Currently in iteration  1611
# Currently in iteration  1612
# Currently in iteration  1613
# Currently in iteration  1614
# Currently in iteration  1615
# Currently in iteration  1616
# Currently in iteration  1617
# Currently in iteration  1618
# Currently in iteration  1619
# Currently in iteration  1620
# Currently in iteration  1621
# Currently in iteration  1622
# Currently in iteration  1623
# Currently in iteration  1624
# Currently in iteration  1625
# Currently in iteration  1626
# Currently in iteration  1627
# Currently in iteration  1628
# Currently in iteration  1629
# Currently in iteration  1630
# Currently in iteration  1631
# Currently in iteration  1632
# Currently in iteration  1633
# Currently in iteration  1634
# Currently in iteration  1635
# Currently in iteration  1636
# Currently in iteration  1637
# Currently in iteration  1638
# Currently in iteration  1639
# Currently in iteration  1640
# Currently in iteration  1641
# Currently in iteration  1642
# Currently in iteration  1643
# Currently in iteration  1644
# Currently in iteration  1645
# Currently in iteration  1646
# Currently in iteration  1647
# Currently in iteration  1648
# Currently in iteration  1649
# Currently in iteration  1650
# Currently in iteration  1651
# Currently in iteration  1652
# Currently in iteration  1653
# Currently in iteration  1654
# Currently in iteration  1655
# Currently in iteration  1656
# Currently in iteration  1657
# Currently in iteration  1658
# Currently in iteration  1659
# Currently in iteration  1660
# Currently in iteration  1661
# Currently in iteration  1662
# Currently in iteration  1663
# Currently in iteration  1664
# Currently in iteration  1665
# Currently in iteration  1666
# Currently in iteration  1667
# Currently in iteration  1668
# Currently in iteration  1669
# Currently in iteration  1670
# Currently in iteration  1671
# Currently in iteration  1672
# Currently in iteration  1673
# Currently in iteration  1674
# Currently in iteration  1675
# Currently in iteration  1676
# Currently in iteration  1677
# Currently in iteration  1678
# Currently in iteration  1679
# Currently in iteration  1680
# Currently in iteration  1681
# Currently in iteration  1682
# Currently in iteration  1683
# Currently in iteration  1684
# Currently in iteration  1685
# Currently in iteration  1686
# Currently in iteration  1687
# Currently in iteration  1688
# Currently in iteration  1689
# Currently in iteration  1690
# Currently in iteration  1691
# Currently in iteration  1692
# Currently in iteration  1693
# ...
# Currently in iteration  2799
# Currently in iteration  2800
# Currently in iteration  2801
# Currently in iteration  2802
# Currently in iteration  2803
# Currently in iteration  2804
# Currently in iteration  2805
# Currently in iteration  2806
# Currently in iteration  2807
# Currently in iteration  2808
# Currently in iteration  2809
# Currently in iteration  2810
# Currently in iteration  2811
# Currently in iteration  2812
# Currently in iteration  2813
# Currently in iteration  2814
# Currently in iteration  2815
# Currently in iteration  2816
# Currently in iteration  2817
# Currently in iteration  2818
# Currently in iteration  2819
# Currently in iteration  2820
# Currently in iteration  2821
# Currently in iteration  2822
# Currently in iteration  2823
# Currently in iteration  2824
# Currently in iteration  2825
# Currently in iteration  2826
# Currently in iteration  2827
# Currently in iteration  2828
# Currently in iteration  2829
# Currently in iteration  2830
# Currently in iteration  2831
# Currently in iteration  2832
# Currently in iteration  2833
# Currently in iteration  2834
# Currently in iteration  2835
# Currently in iteration  2836
# Currently in iteration  2837
# Currently in iteration  2838
# Currently in iteration  2839
# Currently in iteration  2840
# Currently in iteration  2841
# Currently in iteration  2842
# Currently in iteration  2843
# Currently in iteration  2844
# Currently in iteration  2845
# Currently in iteration  2846
# Currently in iteration  2847
# Currently in iteration  2848
# Currently in iteration  2849
# Currently in iteration  2850
# Currently in iteration  2851
# Currently in iteration  2852
# Currently in iteration  2853
# Currently in iteration  2854
# Currently in iteration  2855
# Currently in iteration  2856
# Currently in iteration  2857
# Currently in iteration  2858
# Currently in iteration  2859
# Currently in iteration  2860
# Currently in iteration  2861
# Currently in iteration  2862
# Currently in iteration  2863
# Currently in iteration  2864
# Currently in iteration  2865
# Currently in iteration  2866
# Currently in iteration  2867
# Currently in iteration  2868
# Currently in iteration  2869
# Currently in iteration  2870
# Currently in iteration  2871
# Currently in iteration  2872
# Currently in iteration  2873
# Currently in iteration  2874
# Currently in iteration  2875
# Currently in iteration  2876
# Currently in iteration  2877
# Currently in iteration  2878
# Currently in iteration  2879
# Currently in iteration  2880
# Currently in iteration  2881
# Currently in iteration  2882
# Currently in iteration  2883
# Currently in iteration  2884
# Currently in iteration  2885
# Currently in iteration  2886
# Currently in iteration  2887
# Currently in iteration  2888
# Currently in iteration  2889
# Currently in iteration  2890
# Currently in iteration  2891
# Currently in iteration  2892
# Currently in iteration  2893
# Currently in iteration  2894
# Currently in iteration  2895
# Currently in iteration  2896
# Currently in iteration  2897
# Currently in iteration  2898
# Currently in iteration  2899
# Currently in iteration  2900
# Currently in iteration  2901
# Currently in iteration  2902
# Currently in iteration  2903
# Currently in iteration  2904
# Currently in iteration  2905
# Currently in iteration  2906
# Currently in iteration  2907
# Currently in iteration  2908
# Currently in iteration  2909
# Currently in iteration  2910
# Currently in iteration  2911
# Currently in iteration  2912
# Currently in iteration  2913
# Currently in iteration  2914
# Currently in iteration  2915
# Currently in iteration  2916
# Currently in iteration  2917
# Currently in iteration  2918
# Currently in iteration  2919
# Currently in iteration  2920
# Currently in iteration  2921
# Currently in iteration  2922
# Currently in iteration  2923
# Currently in iteration  2924
# Currently in iteration  2925
# Currently in iteration  2926
# Currently in iteration  2927
# Currently in iteration  2928
# Currently in iteration  2929
# Currently in iteration  2930
# Currently in iteration  2931
# Currently in iteration  2932
# Currently in iteration  2933
# Currently in iteration  2934
# Currently in iteration  2935
# Currently in iteration  2936
# Currently in iteration  2937
# Currently in iteration  2938
# Currently in iteration  2939
# Currently in iteration  2940
# Currently in iteration  2941
# Currently in iteration  2942
# Currently in iteration  2943
# Currently in iteration  2944
# Currently in iteration  2945
# Currently in iteration  2946
# Currently in iteration  2947
# Currently in iteration  2948
# Currently in iteration  2949
# Currently in iteration  2950
# Currently in iteration  2951
# Currently in iteration  2952
# Currently in iteration  2953
# Currently in iteration  2954
# Currently in iteration  2955
# Currently in iteration  2956
# Currently in iteration  2957
# Currently in iteration  2958
# Currently in iteration  2959
# Currently in iteration  2960
# Currently in iteration  2961
# Currently in iteration  2962
# Currently in iteration  2963
# Currently in iteration  2964
# Currently in iteration  2965
# Currently in iteration  2966
# Currently in iteration  2967
# Currently in iteration  2968
# Currently in iteration  2969
# Currently in iteration  2970
# Currently in iteration  2971
# Currently in iteration  2972
# Currently in iteration  2973
# Currently in iteration  2974
# Currently in iteration  2975
# Currently in iteration  2976
# Currently in iteration  2977
# Currently in iteration  2978
# Currently in iteration  2979
# Currently in iteration  2980
# Currently in iteration  2981
# Currently in iteration  2982
# Currently in iteration  2983
# Currently in iteration  2984
# Currently in iteration  2985
# Currently in iteration  2986
# Currently in iteration  2987
# Currently in iteration  2988
# Currently in iteration  2989
# Currently in iteration  2990
# Currently in iteration  2991
# Currently in iteration  2992
# Currently in iteration  2993
# Currently in iteration  2994
# Currently in iteration  2995
# Currently in iteration  2996
# Currently in iteration  2997
# Currently in iteration  2998
# Currently in iteration  2999
# Currently in iteration  3000
# Currently in iteration  3001
# Currently in iteration  3002
# Currently in iteration  3003
# Currently in iteration  3004
# Currently in iteration  3005
# Currently in iteration  3006
# Currently in iteration  3007
# Currently in iteration  3008
# Currently in iteration  3009
# Currently in iteration  3010
# Currently in iteration  3011
# Currently in iteration  3012
# Currently in iteration  3013
# Currently in iteration  3014
# Currently in iteration  3015
# Currently in iteration  3016
# Currently in iteration  3017
# Currently in iteration  3018
# Currently in iteration  3019
# Currently in iteration  3020
# Currently in iteration  3021
# Currently in iteration  3022
# Currently in iteration  3023
# Currently in iteration  3024
# Currently in iteration  3025
# Currently in iteration  3026
# Currently in iteration  3027
# Currently in iteration  3028
# Currently in iteration  3029
# Currently in iteration  3030
# Currently in iteration  3031
# Currently in iteration  3032
# Currently in iteration  3033
# Currently in iteration  3034
# Currently in iteration  3035
# Currently in iteration  3036
# Currently in iteration  3037
# Currently in iteration  3038
# Currently in iteration  3039
# Currently in iteration  3040
# Currently in iteration  3041
# Currently in iteration  3042
# Currently in iteration  3043
# Currently in iteration  3044
# Currently in iteration  3045
# Currently in iteration  3046
# Currently in iteration  3047
# Currently in iteration  3048
# Currently in iteration  3049
# Currently in iteration  3050
# Currently in iteration  3051
# Currently in iteration  3052
# Currently in iteration  3053
# Currently in iteration  3054
# Currently in iteration  3055
# Currently in iteration  3056
# Currently in iteration  3057
# Currently in iteration  3058
# Currently in iteration  3059
# Currently in iteration  3060
# Currently in iteration  3061
# Currently in iteration  3062
# Currently in iteration  3063
# Currently in iteration  3064
# Currently in iteration  3065
# Currently in iteration  3066
# Currently in iteration  3067
# Currently in iteration  3068
# Currently in iteration  3069
# Currently in iteration  3070
# Currently in iteration  3071
# Currently in iteration  3072
# Currently in iteration  3073
# Currently in iteration  3074
# Currently in iteration  3075
# Currently in iteration  3076
# Currently in iteration  3077
# Currently in iteration  3078
# Currently in iteration  3079
# Currently in iteration  3080
# Currently in iteration  3081
# Currently in iteration  3082
# Currently in iteration  3083
# Currently in iteration  3084
# Currently in iteration  3085
# Currently in iteration  3086
# Currently in iteration  3087
# Currently in iteration  3088
# Currently in iteration  3089
# Currently in iteration  3090
# Currently in iteration  3091
# Currently in iteration  3092
# Currently in iteration  3093
# Currently in iteration  3094
# Currently in iteration  3095
# Currently in iteration  3096
# Currently in iteration  3097
# Currently in iteration  3098
# Currently in iteration  3099
# Currently in iteration  3100
# Currently in iteration  3101
# Currently in iteration  3102
# Currently in iteration  3103
# Currently in iteration  3104
# Currently in iteration  3105
# Currently in iteration  3106
# Currently in iteration  3107
# Currently in iteration  3108
# Currently in iteration  3109
# Currently in iteration  3110
# Currently in iteration  3111
# Currently in iteration  3112
# Currently in iteration  3113
# Currently in iteration  3114
# Currently in iteration  3115
# Currently in iteration  3116
# Currently in iteration  3117
# Currently in iteration  3118
# Currently in iteration  3119
# Currently in iteration  3120
# Currently in iteration  3121
# Currently in iteration  3122
# Currently in iteration  3123
# Currently in iteration  3124
# Currently in iteration  3125
# Currently in iteration  3126
# Currently in iteration  3127
# Currently in iteration  3128
# Currently in iteration  3129
# Currently in iteration  3130
# Currently in iteration  3131
# Currently in iteration  3132
# Currently in iteration  3133
# Currently in iteration  3134
# Currently in iteration  3135
# Currently in iteration  3136
# Currently in iteration  3137
# Currently in iteration  3138
# Currently in iteration  3139
# Currently in iteration  3140
# Currently in iteration  3141
# Currently in iteration  3142
# Currently in iteration  3143
# Currently in iteration  3144
# Currently in iteration  3145
# Currently in iteration  3146
# Currently in iteration  3147
# Currently in iteration  3148
# Currently in iteration  3149
# Currently in iteration  3150
# Currently in iteration  3151
# Currently in iteration  3152
# Currently in iteration  3153
# Currently in iteration  3154
# Currently in iteration  3155
# Currently in iteration  3156
# Currently in iteration  3157
# Currently in iteration  3158
# Currently in iteration  3159
# Currently in iteration  3160
# Currently in iteration  3161
# Currently in iteration  3162
# Currently in iteration  3163
# Currently in iteration  3164
# Currently in iteration  3165
# Currently in iteration  3166
# Currently in iteration  3167
# Currently in iteration  3168
# Currently in iteration  3169
# Currently in iteration  3170
# Currently in iteration  3171
# Currently in iteration  3172
# Currently in iteration  3173
# Currently in iteration  3174
# Currently in iteration  3175
# Currently in iteration  3176
# Currently in iteration  3177
# Currently in iteration  3178
# Currently in iteration  3179
# Currently in iteration  3180
# Currently in iteration  3181
# Currently in iteration  3182
# Currently in iteration  3183
# Currently in iteration  3184
# Currently in iteration  3185
# Currently in iteration  3186
# Currently in iteration  3187
# Currently in iteration  3188
# Currently in iteration  3189
# Currently in iteration  3190
# Currently in iteration  3191
# Currently in iteration  3192
# Currently in iteration  3193
# Currently in iteration  3194
# Currently in iteration  3195
# Currently in iteration  3196
# Currently in iteration  3197
# Currently in iteration  3198
# Currently in iteration  3199
# Currently in iteration  3200
# Currently in iteration  3201
# Currently in iteration  3202
# Currently in iteration  3203
# Currently in iteration  3204
# Currently in iteration  3205
# Currently in iteration  3206
# Currently in iteration  3207
# Currently in iteration  3208
# Currently in iteration  3209
# Currently in iteration  3210
# Currently in iteration  3211
# Currently in iteration  3212
# Currently in iteration  3213
# Currently in iteration  3214
# Currently in iteration  3215
# Currently in iteration  3216
# Currently in iteration  3217
# Currently in iteration  3218
# Currently in iteration  3219
# Currently in iteration  3220
# Currently in iteration  3221
# Currently in iteration  3222
# Currently in iteration  3223
# Currently in iteration  3224
# Currently in iteration  3225
# Currently in iteration  3226
# Currently in iteration  3227
# Currently in iteration  3228
# Currently in iteration  3229
# Currently in iteration  3230
# Currently in iteration  3231
# Currently in iteration  3232
# Currently in iteration  3233
# Currently in iteration  3234
# Currently in iteration  3235
# Currently in iteration  3236
# Currently in iteration  3237
# Currently in iteration  3238
# Currently in iteration  3239
# Currently in iteration  3240
# Currently in iteration  3241
# Currently in iteration  3242
# Currently in iteration  3243
# Currently in iteration  3244
# Currently in iteration  3245
# Currently in iteration  3246
# Currently in iteration  3247
# Currently in iteration  3248
# Currently in iteration  3249
# Currently in iteration  3250
# Currently in iteration  3251
# Currently in iteration  3252
# Currently in iteration  3253
# Currently in iteration  3254
# Currently in iteration  3255
# Currently in iteration  3256
# Currently in iteration  3257
# Currently in iteration  3258
# Currently in iteration  3259
# Currently in iteration  3260
# Currently in iteration  3261
# Currently in iteration  3262
# Currently in iteration  3263
# Currently in iteration  3264
# Currently in iteration  3265
# Currently in iteration  3266
# Currently in iteration  3267
# Currently in iteration  3268
# Currently in iteration  3269
# Currently in iteration  3270
# Currently in iteration  3271
# Currently in iteration  3272
# Currently in iteration  3273
# Currently in iteration  3274
# Currently in iteration  3275
# Currently in iteration  3276
# Currently in iteration  3277
# Currently in iteration  3278
# Currently in iteration  3279
# Currently in iteration  3280
# Currently in iteration  3281
# Currently in iteration  3282
# Currently in iteration  3283
# Currently in iteration  3284
# Currently in iteration  3285
# Currently in iteration  3286
# Currently in iteration  3287
# Currently in iteration  3288
# Currently in iteration  3289
# Currently in iteration  3290
# Currently in iteration  3291
# Currently in iteration  3292
# Currently in iteration  3293
# Currently in iteration  3294
# Currently in iteration  3295
# Currently in iteration  3296
# Currently in iteration  3297
# Currently in iteration  3298
# Currently in iteration  3299
# Currently in iteration  3300
# Currently in iteration  3301
# Currently in iteration  3302
# Currently in iteration  3303
# Currently in iteration  3304
# Currently in iteration  3305
# Currently in iteration  3306
# Currently in iteration  3307
# Currently in iteration  3308
# Currently in iteration  3309
# Currently in iteration  3310
# Currently in iteration  3311
# Currently in iteration  3312
# Currently in iteration  3313
# Currently in iteration  3314
# Currently in iteration  3315
# Currently in iteration  3316
# Currently in iteration  3317
# Currently in iteration  3318
# Currently in iteration  3319
# Currently in iteration  3320
# Currently in iteration  3321
# Currently in iteration  3322
# Currently in iteration  3323
# Currently in iteration  3324
# Currently in iteration  3325
# Currently in iteration  3326
# Currently in iteration  3327
# Currently in iteration  3328
# Currently in iteration  3329
# Currently in iteration  3330
# Currently in iteration  3331
# Currently in iteration  3332
# Currently in iteration  3333
# Currently in iteration  3334
# Currently in iteration  3335
# Currently in iteration  3336
# Currently in iteration  3337
# Currently in iteration  3338
# Currently in iteration  3339
# Currently in iteration  3340
# Currently in iteration  3341
# Currently in iteration  3342
# Currently in iteration  3343
# Currently in iteration  3344
# Currently in iteration  3345
# Currently in iteration  3346
# Currently in iteration  3347
# Currently in iteration  3348
# Currently in iteration  3349
# 3349

# %%
# find the accuracy on the test set:
test_data = np.load('utils/assign_1_data_2_test.npy')

final_error = 0
for k in range(150):
	data = np.reshape(test_data[k], (3,1))
	#print data.shape
	predicted = score(data, weights)
	error = data[0] - predicted
	final_error += error**2
print final_error

# %%
# Bonus
# Can you adjust the learning rate alpha in a better way?

# %% [markdown]
# # EM algorithm
#
# This is a general framework for likelihood-based parameter estimation.
# A basic outline of this algorithm is:
#
# * start with initial guesses of parameters
#
# * E step: estimate memberships given params
#
# * M step: estimate params given memberships
#
# * Repeat until convergence
#
# ** Refer to [this link](http://www.rmki.kfki.hu/~banmi/elte/bishop_em.pdf) (9.2.2) .**

# %% [markdown]
# ## Question 3
#
# Let ${\displaystyle \mathbf {x} =(\mathbf {x} _{1},\mathbf {x} _{2},\ldots ,\mathbf {x} _{n})} $ be a sample of $n$ independent observations from a mixture of two multivariate normal distributions of dimension $d$ , and let ${\displaystyle \mathbf {z} =(z_{1},z_{2},\ldots ,z_{n})} $ be the latent variables that determine the component from which the observation originates.
#
# $X_i |(Z_i = 1) \sim \mathcal{N}_d(\boldsymbol{\mu}_1,\Sigma_1)$ and $X_i |(Z_i = 2) \sim \mathcal{N}_d(\boldsymbol{\mu}_2,\Sigma_2)$
#
# The aim is to estimate the unknown parameters representing the mixing value between the Gaussians and the means and covariances of each:
#
# $$ \theta = \big( \boldsymbol{\tau},\boldsymbol{\mu}_1,\boldsymbol{\mu}_2,\Sigma_1,\Sigma_2 \big) $$
#
# a) Given the data, find the parameters $\theta$ using EM algorithm.

# %%
# Load the train dataset 
from math import sqrt


#Note: This cell may need multiple tries since singularity of covariance matrix isn't handled

data = np.load('utils/assign_1_data_3.npy')
# The data is a 1000*2 numpy array, where each row is a independent observation, and 
# the columns are measurement in dimension x and y respectively. 
# now write the code to find the parameter theta.
gamma = np.array(np.zeros([1000,2]))
pi = np.random.uniform(0,1,(2,1))
mu = np.random.uniform(1,100,(2,2))
#sigma = np.random.uniform(0,1,(2,2,2))
sigma = np.array([[[1,0],[0,1]],[[10,0],[0,10]]])
#print sigma.shape
step = 0
def multivariateNormal(x_n, mu_k, sigma_k):
	exponent = -0.5*(np.matmul(np.matmul(np.transpose(x_n - mu_k),np.linalg.inv(sigma_k)), (x_n - mu_k)))
	#print exponent
	#print np.linalg.det(sigma_k)
	#print sigma_k
	#print exponent
	#print sqrt((1/(2*3.14*abs(np.linalg.det(sigma_k))))) * exp(exponent)
	return sqrt((1/(2*3.14*abs(np.linalg.det(sigma_k))))) * exp(exponent)
for i in range(100):
	''' The E step '''
	for n in range(1000):
		for k in range(2):
			numerator = pi[k] * multivariateNormal(np.reshape(data[n],(2,1)), np.reshape(mu[k], (2,1)), sigma[k])
			denominator = pi[0] * multivariateNormal(np.reshape(data[n],(2,1)), np.reshape(mu[0], (2,1)), sigma[0]) + pi[1] * multivariateNormal(np.reshape(data[n],(2,1)), np.reshape(mu[1], (2,1)), sigma[1])
			gamma[n,k] = float(numerator)/denominator

	''' The M step '''
	N = np.sum(gamma, axis=0)

	for k in range(2):
		sum_mu = 0
		for n in range(1000):
			sum_mu += gamma[n,k] * data[n]
		mu[k] = sum_mu/N[k]
	
	for k in range(2):
		sum_gamma = np.zeros((2,2))
		for n in range(1000):
			inter = np.reshape(data[n],(2,1)) - np.reshape(mu[k], (2,1))
			sum_gamma += gamma[n,k]*(np.matmul(inter,np.transpose(inter)))
		sigma[k] = (1/N[k])*sum_gamma
	for k in range(2):
		N[k] = N[k]/1000
	step += 1
	print "---------"
	print step
	print "Mu is ", mu, "Sigma is", sigma
# Out:
# ---------
# 1
# Mu is  [[ 41.68921421  38.304566  ]
#  [ 55.2677562   65.47124439]] Sigma is [[[ 11  -2]
#   [ -2   2]]
#
#  [[ 84 -27]
#   [-27 174]]]
# ---------
# 2
# Mu is  [[ 43.9707313   39.8989283 ]
#  [ 55.39907389  65.78111617]] Sigma is [[[ 23  -3]
#   [ -3   3]]
#
#  [[ 83 -31]
#   [-31 168]]]
# ---------
# 3
# Mu is  [[ 44.92522135  41.68138988]
#  [ 55.63276081  66.32553961]] Sigma is [[[ 29  -3]
#   [ -3   5]]
#
#  [[ 82 -37]
#   [-37 159]]]
# ---------
# 4
# Mu is  [[ 47.17195369  43.52882184]
#  [ 55.81091822  66.97938068]] Sigma is [[[ 29   2]
#   [  2   8]]
#
#  [[ 83 -42]
#   [-42 151]]]
# ---------
# 5
# Mu is  [[ 49.67578762  45.70983765]
#  [ 55.97150946  68.0404623 ]] Sigma is [[[ 34   7]
#   [  7  12]]
#
#  [[ 86 -47]
#   [-47 139]]]
# ---------
# 6
# Mu is  [[ 52.30133366  47.97063516]
#  [ 55.8958947   69.40376536]] Sigma is [[[ 44  13]
#   [ 13  19]]
#
#  [[ 91 -50]
#   [-50 126]]]
# ---------
# 7
# Mu is  [[ 54.7099968   50.27333818]
#  [ 55.41240436  71.05347504]] Sigma is [[[ 57  21]
#   [ 21  28]]
#
#  [[ 94 -48]
#   [-48 114]]]
# ---------
# 8
# Mu is  [[ 56.99552346  52.41693179]
#  [ 54.19111191  72.89274136]] Sigma is [[[ 73  31]
#   [ 31  37]]
#
#  [[ 88 -38]
#   [-38 102]]]
# ---------
# 9
# Mu is  [[ 58.84583832  53.99522788]
#  [ 52.35164803  74.38342308]] Sigma is [[[ 91  44]
#   [ 44  48]]
#
#  [[ 60 -23]
#   [-23  94]]]
# ---------
# 10
# Mu is  [[ 59.87236238  54.86188105]
#  [ 50.86235468  75.22777937]] Sigma is [[[97 50]
#   [50 54]]
#
#  [[32 -9]
#   [-9 89]]]
# ---------
# 11
# Mu is  [[ 60.20913733  55.17988859]
#  [ 50.19283145  75.65345139]] Sigma is [[[95 51]
#   [51 56]]
#
#  [[22 -1]
#   [-1 86]]]
# ---------
# 12
# Mu is  [[ 60.27775243  55.32644184]
#  [ 49.93784414  75.87506202]] Sigma is [[[93 50]
#   [50 57]]
#
#  [[20  1]
#   [ 1 84]]]
# ---------
# 13
# Mu is  [[ 60.23977316  55.40616207]
#  [ 49.85707682  76.03103727]] Sigma is [[[92 50]
#   [50 57]]
#
#  [[19  2]
#   [ 2 83]]]
# ---------
# 14
# Mu is  [[ 60.22507799  55.43346582]
#  [ 49.82384893  76.09907897]] Sigma is [[[92 49]
#   [49 57]]
#
#  [[19  3]
#   [ 3 82]]]
# ---------
# 15
# Mu is  [[ 60.18821049  55.46903082]
#  [ 49.80111142  76.18536652]] Sigma is [[[92 49]
#   [49 58]]
#
#  [[19  3]
#   [ 3 81]]]
# ---------
# 16
# Mu is  [[ 60.15908012  55.49277196]
#  [ 49.78973535  76.24583701]] Sigma is [[[92 49]
#   [49 58]]
#
#  [[19  3]
#   [ 3 81]]]
# ---------
# 17
# Mu is  [[ 60.15013442  55.49896759]
#  [ 49.78646535  76.26528779]] Sigma is [[[92 48]
#   [48 58]]
#
#  [[19  3]
#   [ 3 80]]]
# ---------
# 18
# Mu is  [[ 60.12017798  55.52136884]
#  [ 49.77966269  76.32069886]] Sigma is [[[92 48]
#   [48 58]]
#
#  [[19  3]
#   [ 3 80]]]
# ---------
# 19
# Mu is  [[ 60.11171787  55.5271913 ]
#  [ 49.77688345  76.33874805]] Sigma is [[[92 48]
#   [48 58]]
#
#  [[19  3]
#   [ 3 80]]]
# ---------
# 20
# Mu is  [[ 60.10920279  55.52892465]
#  [ 49.77601782  76.34420129]] Sigma is [[[92 48]
#   [48 58]]
#
#  [[19  3]
#   [ 3 79]]]
# ---------
# 21
# Mu is  [[ 60.10230683  55.53012432]
#  [ 49.77511363  76.36017962]] Sigma is [[[92 48]
#   [48 58]]
#
#  [[19  3]
#   [ 3 79]]]
# ---------
# 22
# Mu is  [[ 60.10049629  55.5311875 ]
#  [ 49.77461315  76.36407802]] Sigma is [[[92 48]
#   [48 58]]
#
#  [[19  3]
#   [ 3 79]]]
# ---------
# 23
# Mu is  [[ 60.09997414  55.53154061]
#  [ 49.77444099  76.36520703]] Sigma is [[[92 48]
#   [48 58]]
#
#  [[19  3]
#   [ 3 79]]]
# ---------
# 24
# Mu is  [[ 60.09981895  55.53164851]
#  [ 49.77438761  76.3655438 ]] Sigma is [[[92 48]
#   [48 58]]
#
#  [[19  3]
#   [ 3 79]]]
# ---------
# 25
# Mu is  [[ 60.09977246  55.53168102]
#  [ 49.77437146  76.36564477]] Sigma is [[[92 48]
#   [48 58]]
#
#  [[19  3]
#   [ 3 79]]]
# ---------
# 26
# Mu is  [[ 60.09975852  55.53169079]
#  [ 49.7743666   76.36567508]] Sigma is [[[92 48]
#   [48 58]]
#
#  [[19  3]
#   [ 3 79]]]
# ---------
# 27
# Mu is  [[ 60.09975433  55.53169372]
#  [ 49.77436515  76.36568418]] Sigma is [[[92 48]
#   [48 58]]
#
#  [[19  3]
#   [ 3 79]]]
# ---------
# 28
# Mu is  [[ 60.09975307  55.5316946 ]
#  [ 49.77436471  76.36568692]] Sigma is [[[92 48]
#   [48 58]]
#
#  [[19  3]
#   [ 3 79]]]
# ---------
# 29
# Mu is  [[ 60.09975269  55.53169487]
#  [ 49.77436458  76.36568774]] Sigma is [[[92 48]
#   [48 58]]
#
#  [[19  3]
#   [ 3 79]]]
# ---------
# 30
# Mu is  [[ 60.09975258  55.53169495]
#  [ 49.77436454  76.36568798]] Sigma is [[[92 48]
#   [48 58]]
#
#  [[19  3]
#   [ 3 79]]]
# ---------
# 31
# Mu is  [[ 60.09975255  55.53169497]
#  [ 49.77436452  76.36568806]] Sigma is [[[92 48]
#   [48 58]]
#
#  [[19  3]
#   [ 3 79]]]
# ---------
# 32
# Mu is  [[ 60.09975254  55.53169498]
#  [ 49.77436452  76.36568808]] Sigma is [[[92 48]
#   [48 58]]
#
#  [[19  3]
#   [ 3 79]]]
# ---------
# 33
# Mu is  [[ 60.09975253  55.53169498]
#  [ 49.77436452  76.36568808]] Sigma is [[[92 48]
#   [48 58]]
#
#  [[19  3]
#   [ 3 79]]]
# ---------
# 34
# Mu is  [[ 60.09975253  55.53169498]
#  [ 49.77436452  76.36568809]] Sigma is [[[92 48]
#   [48 58]]
#
#  [[19  3]
#   [ 3 79]]]
# ---------
# 35
# Mu is  [[ 60.09975253  55.53169498]
#  [ 49.77436452  76.36568809]] Sigma is [[[92 48]
#   [48 58]]
#
#  [[19  3]
#   [ 3 79]]]
# ---------
# 36
# Mu is  [[ 60.09975253  55.53169498]
#  [ 49.77436452  76.36568809]] Sigma is [[[92 48]
#   [48 58]]
#
#  [[19  3]
#   [ 3 79]]]
# ---------
# 37
# Mu is  [[ 60.09975253  55.53169498]
#  [ 49.77436452  76.36568809]] Sigma is [[[92 48]
#   [48 58]]
#
#  [[19  3]
#   [ 3 79]]]
# ---------
# 38
# Mu is  [[ 60.09975253  55.53169498]
#  [ 49.77436452  76.36568809]] Sigma is [[[92 48]
#   [48 58]]
#
#  [[19  3]
#   [ 3 79]]]
# ---------
# 39
# Mu is  [[ 60.09975253  55.53169498]
#  [ 49.77436452  76.36568809]] Sigma is [[[92 48]
#   [48 58]]
#
#  [[19  3]
#   [ 3 79]]]
# ---------
# 40
# Mu is  [[ 60.09975253  55.53169498]
#  [ 49.77436452  76.36568809]] Sigma is [[[92 48]
#   [48 58]]
#
#  [[19  3]
#   [ 3 79]]]
# ---------
# 41
# Mu is  [[ 60.09975253  55.53169498]
#  [ 49.77436452  76.36568809]] Sigma is [[[92 48]
#   [48 58]]
#
#  [[19  3]
#   [ 3 79]]]
# ---------
# 42
# Mu is  [[ 60.09975253  55.53169498]
#  [ 49.77436452  76.36568809]] Sigma is [[[92 48]
#   [48 58]]
#
#  [[19  3]
#   [ 3 79]]]
# ---------
# 43
# Mu is  [[ 60.09975253  55.53169498]
#  [ 49.77436452  76.36568809]] Sigma is [[[92 48]
#   [48 58]]
#
#  [[19  3]
#   [ 3 79]]]
# ---------
# 44
# Mu is  [[ 60.09975253  55.53169498]
#  [ 49.77436452  76.36568809]] Sigma is [[[92 48]
#   [48 58]]
#
#  [[19  3]
#   [ 3 79]]]
# ---------
# 45
# Mu is  [[ 60.09975253  55.53169498]
#  [ 49.77436452  76.36568809]] Sigma is [[[92 48]
#   [48 58]]
#
#  [[19  3]
#   [ 3 79]]]
# ---------
# 46
# Mu is  [[ 60.09975253  55.53169498]
#  [ 49.77436452  76.36568809]] Sigma is [[[92 48]
#   [48 58]]
#
#  [[19  3]
#   [ 3 79]]]
# ---------
# 47
# Mu is  [[ 60.09975253  55.53169498]
#  [ 49.77436452  76.36568809]] Sigma is [[[92 48]
#   [48 58]]
#
#  [[19  3]
#   [ 3 79]]]
# ---------
# 48
# Mu is  [[ 60.09975253  55.53169498]
#  [ 49.77436452  76.36568809]] Sigma is [[[92 48]
#   [48 58]]
#
#  [[19  3]
#   [ 3 79]]]
# ---------
# 49
# Mu is  [[ 60.09975253  55.53169498]
#  [ 49.77436452  76.36568809]] Sigma is [[[92 48]
#   [48 58]]
#
#  [[19  3]
#   [ 3 79]]]
# ---------
# 50
# Mu is  [[ 60.09975253  55.53169498]
#  [ 49.77436452  76.36568809]] Sigma is [[[92 48]
#   [48 58]]
#
#  [[19  3]
#   [ 3 79]]]
# ---------
# 51
# Mu is  [[ 60.09975253  55.53169498]
#  [ 49.77436452  76.36568809]] Sigma is [[[92 48]
#   [48 58]]
#
#  [[19  3]
#   [ 3 79]]]
# ---------
# 52
# Mu is  [[ 60.09975253  55.53169498]
#  [ 49.77436452  76.36568809]] Sigma is [[[92 48]
#   [48 58]]
#
#  [[19  3]
#   [ 3 79]]]
# ---------
# 53
# Mu is  [[ 60.09975253  55.53169498]
#  [ 49.77436452  76.36568809]] Sigma is [[[92 48]
#   [48 58]]
#
#  [[19  3]
#   [ 3 79]]]
# ---------
# 54
# Mu is  [[ 60.09975253  55.53169498]
#  [ 49.77436452  76.36568809]] Sigma is [[[92 48]
#   [48 58]]
#
#  [[19  3]
#   [ 3 79]]]
# ---------
# 55
# Mu is  [[ 60.09975253  55.53169498]
#  [ 49.77436452  76.36568809]] Sigma is [[[92 48]
#   [48 58]]
#
#  [[19  3]
#   [ 3 79]]]
# ---------
# 56
# Mu is  [[ 60.09975253  55.53169498]
#  [ 49.77436452  76.36568809]] Sigma is [[[92 48]
#   [48 58]]
#
#  [[19  3]
#   [ 3 79]]]
# ---------
# 57
# Mu is  [[ 60.09975253  55.53169498]
#  [ 49.77436452  76.36568809]] Sigma is [[[92 48]
#   [48 58]]
#
#  [[19  3]
#   [ 3 79]]]
# ---------
# 58
# Mu is  [[ 60.09975253  55.53169498]
#  [ 49.77436452  76.36568809]] Sigma is [[[92 48]
#   [48 58]]
#
#  [[19  3]
#   [ 3 79]]]
# ---------
# 59
# Mu is  [[ 60.09975253  55.53169498]
#  [ 49.77436452  76.36568809]] Sigma is [[[92 48]
#   [48 58]]
#
#  [[19  3]
#   [ 3 79]]]
# ---------
# 60
# Mu is  [[ 60.09975253  55.53169498]
#  [ 49.77436452  76.36568809]] Sigma is [[[92 48]
#   [48 58]]
#
#  [[19  3]
#   [ 3 79]]]
# ---------
# 61
# Mu is  [[ 60.09975253  55.53169498]
#  [ 49.77436452  76.36568809]] Sigma is [[[92 48]
#   [48 58]]
#
#  [[19  3]
#   [ 3 79]]]
# ---------
# 62
# Mu is  [[ 60.09975253  55.53169498]
#  [ 49.77436452  76.36568809]] Sigma is [[[92 48]
#   [48 58]]
#
#  [[19  3]
#   [ 3 79]]]
# ---------
# 63
# Mu is  [[ 60.09975253  55.53169498]
#  [ 49.77436452  76.36568809]] Sigma is [[[92 48]
#   [48 58]]
#
#  [[19  3]
#   [ 3 79]]]
# ---------
# 64
# Mu is  [[ 60.09975253  55.53169498]
#  [ 49.77436452  76.36568809]] Sigma is [[[92 48]
#   [48 58]]
#
#  [[19  3]
#   [ 3 79]]]
# ---------
# 65
# Mu is  [[ 60.09975253  55.53169498]
#  [ 49.77436452  76.36568809]] Sigma is [[[92 48]
#   [48 58]]
#
#  [[19  3]
#   [ 3 79]]]
# ---------
# 66
# Mu is  [[ 60.09975253  55.53169498]
#  [ 49.77436452  76.36568809]] Sigma is [[[92 48]
#   [48 58]]
#
#  [[19  3]
#   [ 3 79]]]
# ---------
# 67
# Mu is  [[ 60.09975253  55.53169498]
#  [ 49.77436452  76.36568809]] Sigma is [[[92 48]
#   [48 58]]
#
#  [[19  3]
#   [ 3 79]]]
# ---------
# 68
# Mu is  [[ 60.09975253  55.53169498]
#  [ 49.77436452  76.36568809]] Sigma is [[[92 48]
#   [48 58]]
#
#  [[19  3]
#   [ 3 79]]]
# ---------
# 69
# Mu is  [[ 60.09975253  55.53169498]
#  [ 49.77436452  76.36568809]] Sigma is [[[92 48]
#   [48 58]]
#
#  [[19  3]
#   [ 3 79]]]
# ---------
# 70
# Mu is  [[ 60.09975253  55.53169498]
#  [ 49.77436452  76.36568809]] Sigma is [[[92 48]
#   [48 58]]
#
#  [[19  3]
#   [ 3 79]]]
# ---------
# 71
# Mu is  [[ 60.09975253  55.53169498]
#  [ 49.77436452  76.36568809]] Sigma is [[[92 48]
#   [48 58]]
#
#  [[19  3]
#   [ 3 79]]]
# ---------
# 72
# Mu is  [[ 60.09975253  55.53169498]
#  [ 49.77436452  76.36568809]] Sigma is [[[92 48]
#   [48 58]]
#
#  [[19  3]
#   [ 3 79]]]
# ---------
# 73
# Mu is  [[ 60.09975253  55.53169498]
#  [ 49.77436452  76.36568809]] Sigma is [[[92 48]
#   [48 58]]
#
#  [[19  3]
#   [ 3 79]]]
# ---------
# 74
# Mu is  [[ 60.09975253  55.53169498]
#  [ 49.77436452  76.36568809]] Sigma is [[[92 48]
#   [48 58]]
#
#  [[19  3]
#   [ 3 79]]]
# ---------
# 75
# Mu is  [[ 60.09975253  55.53169498]
#  [ 49.77436452  76.36568809]] Sigma is [[[92 48]
#   [48 58]]
#
#  [[19  3]
#   [ 3 79]]]
# ---------
# 76
# Mu is  [[ 60.09975253  55.53169498]
#  [ 49.77436452  76.36568809]] Sigma is [[[92 48]
#   [48 58]]
#
#  [[19  3]
#   [ 3 79]]]
# ---------
# 77
# Mu is  [[ 60.09975253  55.53169498]
#  [ 49.77436452  76.36568809]] Sigma is [[[92 48]
#   [48 58]]
#
#  [[19  3]
#   [ 3 79]]]
# ---------
# 78
# Mu is  [[ 60.09975253  55.53169498]
#  [ 49.77436452  76.36568809]] Sigma is [[[92 48]
#   [48 58]]
#
#  [[19  3]
#   [ 3 79]]]
# ---------
# 79
# Mu is  [[ 60.09975253  55.53169498]
#  [ 49.77436452  76.36568809]] Sigma is [[[92 48]
#   [48 58]]
#
#  [[19  3]
#   [ 3 79]]]
# ---------
# 80
# Mu is  [[ 60.09975253  55.53169498]
#  [ 49.77436452  76.36568809]] Sigma is [[[92 48]
#   [48 58]]
#
#  [[19  3]
#   [ 3 79]]]
# ---------
# 81
# Mu is  [[ 60.09975253  55.53169498]
#  [ 49.77436452  76.36568809]] Sigma is [[[92 48]
#   [48 58]]
#
#  [[19  3]
#   [ 3 79]]]
# ---------
# 82
# Mu is  [[ 60.09975253  55.53169498]
#  [ 49.77436452  76.36568809]] Sigma is [[[92 48]
#   [48 58]]
#
#  [[19  3]
#   [ 3 79]]]
# ---------
# 83
# Mu is  [[ 60.09975253  55.53169498]
#  [ 49.77436452  76.36568809]] Sigma is [[[92 48]
#   [48 58]]
#
#  [[19  3]
#   [ 3 79]]]
# ---------
# 84
# Mu is  [[ 60.09975253  55.53169498]
#  [ 49.77436452  76.36568809]] Sigma is [[[92 48]
#   [48 58]]
#
#  [[19  3]
#   [ 3 79]]]
# ---------
# 85
# Mu is  [[ 60.09975253  55.53169498]
#  [ 49.77436452  76.36568809]] Sigma is [[[92 48]
#   [48 58]]
#
#  [[19  3]
#   [ 3 79]]]
# ---------
# 86
# Mu is  [[ 60.09975253  55.53169498]
#  [ 49.77436452  76.36568809]] Sigma is [[[92 48]
#   [48 58]]
#
#  [[19  3]
#   [ 3 79]]]
# ---------
# 87
# Mu is  [[ 60.09975253  55.53169498]
#  [ 49.77436452  76.36568809]] Sigma is [[[92 48]
#   [48 58]]
#
#  [[19  3]
#   [ 3 79]]]
# ---------
# 88
# Mu is  [[ 60.09975253  55.53169498]
#  [ 49.77436452  76.36568809]] Sigma is [[[92 48]
#   [48 58]]
#
#  [[19  3]
#   [ 3 79]]]
# ---------
# 89
# Mu is  [[ 60.09975253  55.53169498]
#  [ 49.77436452  76.36568809]] Sigma is [[[92 48]
#   [48 58]]
#
#  [[19  3]
#   [ 3 79]]]
# ---------
# 90
# Mu is  [[ 60.09975253  55.53169498]
#  [ 49.77436452  76.36568809]] Sigma is [[[92 48]
#   [48 58]]
#
#  [[19  3]
#   [ 3 79]]]
# ---------
# 91
# Mu is  [[ 60.09975253  55.53169498]
#  [ 49.77436452  76.36568809]] Sigma is [[[92 48]
#   [48 58]]
#
#  [[19  3]
#   [ 3 79]]]
# ---------
# 92
# Mu is  [[ 60.09975253  55.53169498]
#  [ 49.77436452  76.36568809]] Sigma is [[[92 48]
#   [48 58]]
#
#  [[19  3]
#   [ 3 79]]]
# ---------
# 93
# Mu is  [[ 60.09975253  55.53169498]
#  [ 49.77436452  76.36568809]] Sigma is [[[92 48]
#   [48 58]]
#
#  [[19  3]
#   [ 3 79]]]
# ---------
# 94
# Mu is  [[ 60.09975253  55.53169498]
#  [ 49.77436452  76.36568809]] Sigma is [[[92 48]
#   [48 58]]
#
#  [[19  3]
#   [ 3 79]]]
# ---------
# 95
# Mu is  [[ 60.09975253  55.53169498]
#  [ 49.77436452  76.36568809]] Sigma is [[[92 48]
#   [48 58]]
#
#  [[19  3]
#   [ 3 79]]]
# ---------
# 96
# Mu is  [[ 60.09975253  55.53169498]
#  [ 49.77436452  76.36568809]] Sigma is [[[92 48]
#   [48 58]]
#
#  [[19  3]
#   [ 3 79]]]
# ---------
# 97
# Mu is  [[ 60.09975253  55.53169498]
#  [ 49.77436452  76.36568809]] Sigma is [[[92 48]
#   [48 58]]
#
#  [[19  3]
#   [ 3 79]]]
# ---------
# 98
# Mu is  [[ 60.09975253  55.53169498]
#  [ 49.77436452  76.36568809]] Sigma is [[[92 48]
#   [48 58]]
#
#  [[19  3]
#   [ 3 79]]]
# ---------
# 99
# Mu is  [[ 60.09975253  55.53169498]
#  [ 49.77436452  76.36568809]] Sigma is [[[92 48]
#   [48 58]]
#
#  [[19  3]
#   [ 3 79]]]
# ---------
# 100
# Mu is  [[ 60.09975253  55.53169498]
#  [ 49.77436452  76.36568809]] Sigma is [[[92 48]
#   [48 58]]
#
#  [[19  3]
#   [ 3 79]]]

# %%
# Parameters are given by:
print "Final mu(s) are ", mu
print "Final sigmas are ", sigma
# Out:
# Final mu(s) are  [[ 60.09975253  55.53169498]
#  [ 49.77436452  76.36568809]]
# Final sigmas are  [[[92 48]
#   [48 58]]
#
#  [[19  3]
#   [ 3 79]]]

# %%
# Visualize the entire data by plotting them as points in a 2-D canvas.  
# Show the estimated means and the standard deviations.

# %% [markdown]
# # Clustering
#
# For clustering we covered two algorithms
#
# 1) K-means : An iterative method to get 'K' clusters, initializing them randomly
#
# 2) Hirarchical : An iterative method to get a dendogram of clustering with various numbers of cluster centers.
#
# ### K-means Clustering
#
# We initialize $K$ cluster centers $\{ c_1,c_2 ,... c_k\}$for $K$-clusters randomly. All the data points are assigned a cluster index $D_i \in \{ 1,2,...,k\}$, based on the closest cluster center to each point.
#
# Now, for each cluster, the cluster centers are re-evaluated as the mean of all the points in the center.
#
# $$
# c_i = mean(\{ X_j | D_j = i \})
# $$
# This process continues till convergence.

# %% [markdown]
# ## Question 4
#
# The dataset contains 1000  color images.Convert them to grayscale images. We need to cluster them into various $n$ clusters based on the similarity of their histograms. For each image, find the histogram with bin size 25 (last bin of 30;i.e.225-255;giving you 10 bins). Now treating each of these bins as seperate dimensions, find:
#
# a) Cluster Centers for $n = 5$ clusters, with $L_2$ distance criteria for measuring distance between a pair of images.
#
# b) **Bonus**: Use Earth Movers Distance in the above problem.

# %%
# For this problem we will be using the 1000 test images of CIFAR-10 dataset.
## Load the data from the following link
# https://www.cs.toronto.edu/~kriz/cifar.html
import cPickle

def unpickle(filetoUnpickle):
    with open(filetoUnpickle, 'rb') as fo:
        dict = cPickle.load(fo)
    return dict

#Note: I have added the test_batch files to my utils

filetoUnpickle = 'utils/test_batch'
dict = unpickle(filetoUnpickle)
#print dict['data'].shape
data = dict['data'][:1000,:]
#print data.shape
image_bins = np.zeros((1000, 10))
n = 5
centroids = np.random.uniform(0,100,(5,10))

# %%
# Convert it to grayscale values
def belongsTo(data, centroids):
	min = distance(data,centroids[0])
	index = 0
	for i in range(1,5):
		if distance(data,centroids[i]) < min:
			index = i
	return index

def distance(a, b):
    return np.linalg.norm(a - b)

def togrey(a):
	return (0.2125 * a[0] + 0.7154 * a[1] + 0.0721 * a[2])

def convertToGreyAndBin(image_bins):
	for i in range(1000):
		a = data[i]
		#print a
		b = a.reshape((3,1024))
		#print b
		c = np.transpose(b)
		#print c
		#d = np.reshape(32,32,3)
		e = np.apply_along_axis(togrey, 1, c)
		#print e.shape	
		#grey[i] = e
		for j in range(1024):
			index = e[j]/25
			if int(index) == 10:
				image_bins[i][9] += 1
			else:
				image_bins[i][int(index)] += 1
		#print image_bins[i]
		#print grey[i]
	return image_bins
image_bins =  convertToGreyAndBin(image_bins)

# %%
# find the histograms and get a 10-dimensional representation of each images.

# %%
# Use K-means to find  out the number of cluster centers.
step = 0
for i in range(100):
	step +=1
	c1 = []
	c2 = []
	c3 = []
	c4 = []
	c5 = []
	for j in range(1000):
		index = belongsTo(image_bins[j],centroids)
		if index == 0:
			c1.append(j)
		if index == 1:
			c2.append(j)
		if index == 2:
			c3.append(j)
		if index == 3:
			c4.append(j)
		if index == 4:
			c5.append(j)
	#print c1,c2,c3,c4,c5
	#print len(c1)
	if step > 1:
		prev_centroids = centroids
	if len(c1) > 0:
		centroids[0] = np.mean(np.take(image_bins,c1, axis=0) , axis=0)
	if len(c2) > 0:
		centroids[1] = np.mean(np.take(image_bins,c2, axis=0) , axis=0)
	if len(c3) > 0:
		centroids[2] = np.mean(np.take(image_bins,c3, axis=0) , axis=0)
	if len(c4) > 0:
		centroids[3] = np.mean(np.take(image_bins,c4, axis=0) , axis=0)
	if len(c5) > 0:
		centroids[4] = np.mean(np.take(image_bins,c5, axis=0) , axis=0)

print centroids
# Out:
# [[   15.83333333    14.66666667    39.66666667    79.83333333    86.5
#      94.83333333    90.83333333    91.83333333   117.5         1416.5       ]
#  [    0.            12.5           42.5           57.5          101.5
#    1170.5          507.           122.5           34.             0.        ]
#  [   35.33333333   104.           182.           180.66666667
#     116.66666667    72.            52.            58.            60.66666667
#    1186.66666667]
#  [   20.45454545    79.18181818    97.81818182   135.36363636   150.           131.
#     128.09090909   125.54545455   253.45454545   927.09090909]
#  [   91.94184839   163.25233645   242.03530633   295.65524403
#     310.24299065   282.74350987   247.95430945   191.50363448
#     131.82554517    90.84527518]]

# %%
# Visualize cluster means to see what they look like.

# %% [markdown]
# # References
#
# Useful references will be added shortly.
#
# 1) Linear Regression
#   * [Wikipedia](https://en.wikipedia.org/wiki/Linear_regression)
#
# 2) Logistic Regression
#   * [Wikipedia](https://en.wikipedia.org/wiki/Logistic_regression)
#   * [Win Vector Blog](http://www.win-vector.com/blog/2011/09/the-simpler-derivation-of-logistic-regression/)
#   * [Renselaer Course Slides](http://www.cs.rpi.edu/~magdon/courses/LFD-Slides/SlidesLect09.pdf)
#
# 3) EM
#   * [Cambridge Tutorial](http://www.cs.huji.ac.il/~yweiss/emTutorial.pdf)
#   * [Chapter 9 - Pattern Recognition and Machine Learning by Christopher M. Bishop](http://www.rmki.kfki.hu/~banmi/elte/bishop_em.pdf)
#   * [Wikipedia](https://en.wikipedia.org/wiki/Expectation%E2%80%93maximization_algorithm)
#
# 4) K-means
#   * [Wikipedia](https://en.wikipedia.org/wiki/K-means_clustering)
